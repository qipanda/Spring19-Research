# %%
# Import relevant modules
# %matplotlib notebook

import sys
sys.path.append("../")

from Models.SGNS import SourceReceiverClassifier, SourceReceiverModel
from Preprocessing.FullContextProcessor import FullContextProcessor

import numpy as np
import pandas as pd
import torch
import pickle

# %% [markdown]
# # Std CV Results

# %%
cv_results = pd.read_csv("sr-cv-std-results.txt", sep="\t")
# cv_results.columns
cv_results.loc[:, ["params", "mean_test_Log-Loss"]].sort_values(by="mean_test_Log-Loss", ascending=False)
# Out:
#                                                 params  mean_test_Log-Loss
# 90    {'r_std': 0.0001, 's_std': 0.0001, 'w_std': 0.1}           -1.612109
# 110     {'r_std': 1e-05, 's_std': 0.001, 'w_std': 0.1}           -1.612670
# 20        {'r_std': 0.1, 's_std': 1e-05, 'w_std': 0.1}           -1.612795
# 4         {'r_std': 0.1, 's_std': 0.1, 'w_std': 1e-05}           -1.612898
# 25         {'r_std': 0.01, 's_std': 0.1, 'w_std': 0.1}           -1.612898
# 2         {'r_std': 0.1, 's_std': 0.1, 'w_std': 0.001}           -1.612919
# 70      {'r_std': 0.001, 's_std': 1e-05, 'w_std': 0.1}           -1.613127
# 55       {'r_std': 0.001, 's_std': 0.01, 'w_std': 0.1}           -1.613272
# 80      {'r_std': 0.0001, 's_std': 0.01, 'w_std': 0.1}           -1.614103
# 76      {'r_std': 0.0001, 's_std': 0.1, 'w_std': 0.01}           -1.614394
# 104     {'r_std': 1e-05, 's_std': 0.1, 'w_std': 1e-05}           -1.614498
# 18    {'r_std': 0.1, 's_std': 0.0001, 'w_std': 0.0001}           -1.614560
# 5          {'r_std': 0.1, 's_std': 0.01, 'w_std': 0.1}           -1.614622
# 23     {'r_std': 0.1, 's_std': 1e-05, 'w_std': 0.0001}           -1.614726
# 75       {'r_std': 0.0001, 's_std': 0.1, 'w_std': 0.1}           -1.614872
# 0           {'r_std': 0.1, 's_std': 0.1, 'w_std': 0.1}           -1.615038
# 85     {'r_std': 0.0001, 's_std': 0.001, 'w_std': 0.1}           -1.615121
# 26        {'r_std': 0.01, 's_std': 0.1, 'w_std': 0.01}           -1.615266
# 101      {'r_std': 1e-05, 's_std': 0.1, 'w_std': 0.01}           -1.615370
# 45       {'r_std': 0.01, 's_std': 1e-05, 'w_std': 0.1}           -1.615370
# 29       {'r_std': 0.01, 's_std': 0.1, 'w_std': 1e-05}           -1.615432
# 24      {'r_std': 0.1, 's_std': 1e-05, 'w_std': 1e-05}           -1.615474
# 115    {'r_std': 1e-05, 's_std': 0.0001, 'w_std': 0.1}           -1.615869
# 65     {'r_std': 0.001, 's_std': 0.0001, 'w_std': 0.1}           -1.616014
# 1          {'r_std': 0.1, 's_std': 0.1, 'w_std': 0.01}           -1.616118
# 50        {'r_std': 0.001, 's_std': 0.1, 'w_std': 0.1}           -1.616201
# 102     {'r_std': 1e-05, 's_std': 0.1, 'w_std': 0.001}           -1.616471
# 12      {'r_std': 0.1, 's_std': 0.001, 'w_std': 0.001}           -1.616554
# 51       {'r_std': 0.001, 's_std': 0.1, 'w_std': 0.01}           -1.616637
# 60      {'r_std': 0.001, 's_std': 0.001, 'w_std': 0.1}           -1.616866
# ..                                                 ...                 ...
# 117  {'r_std': 1e-05, 's_std': 0.0001, 'w_std': 0.001}           -1.624426
# 78    {'r_std': 0.0001, 's_std': 0.1, 'w_std': 0.0001}           -1.624510
# 59     {'r_std': 0.001, 's_std': 0.01, 'w_std': 1e-05}           -1.624593
# 86    {'r_std': 0.0001, 's_std': 0.001, 'w_std': 0.01}           -1.624738
# 43   {'r_std': 0.01, 's_std': 0.0001, 'w_std': 0.0001}           -1.625049
# 44    {'r_std': 0.01, 's_std': 0.0001, 'w_std': 1e-05}           -1.625195
# 107    {'r_std': 1e-05, 's_std': 0.01, 'w_std': 0.001}           -1.625216
# 93   {'r_std': 0.0001, 's_std': 0.0001, 'w_std': 0....           -1.625236
# 52      {'r_std': 0.001, 's_std': 0.1, 'w_std': 0.001}           -1.625465
# 97   {'r_std': 0.0001, 's_std': 1e-05, 'w_std': 0.001}           -1.625735
# 73   {'r_std': 0.001, 's_std': 1e-05, 'w_std': 0.0001}           -1.625901
# 58    {'r_std': 0.001, 's_std': 0.01, 'w_std': 0.0001}           -1.625943
# 30        {'r_std': 0.01, 's_std': 0.01, 'w_std': 0.1}           -1.626068
# 69   {'r_std': 0.001, 's_std': 0.0001, 'w_std': 1e-05}           -1.626462
# 74    {'r_std': 0.001, 's_std': 1e-05, 'w_std': 1e-05}           -1.626586
# 64    {'r_std': 0.001, 's_std': 0.001, 'w_std': 1e-05}           -1.626649
# 62    {'r_std': 0.001, 's_std': 0.001, 'w_std': 0.001}           -1.626794
# 61     {'r_std': 0.001, 's_std': 0.001, 'w_std': 0.01}           -1.627397
# 99   {'r_std': 0.0001, 's_std': 1e-05, 'w_std': 1e-05}           -1.628331
# 94   {'r_std': 0.0001, 's_std': 0.0001, 'w_std': 1e...           -1.628497
# 88   {'r_std': 0.0001, 's_std': 0.001, 'w_std': 0.0...           -1.628622
# 123  {'r_std': 1e-05, 's_std': 1e-05, 'w_std': 0.0001}           -1.628975
# 119  {'r_std': 1e-05, 's_std': 0.0001, 'w_std': 1e-05}           -1.629245
# 98   {'r_std': 0.0001, 's_std': 1e-05, 'w_std': 0.0...           -1.630741
# 113  {'r_std': 1e-05, 's_std': 0.001, 'w_std': 0.0001}           -1.631385
# 118  {'r_std': 1e-05, 's_std': 0.0001, 'w_std': 0.0...           -1.632049
# 83   {'r_std': 0.0001, 's_std': 0.01, 'w_std': 0.0001}           -1.632174
# 72    {'r_std': 0.001, 's_std': 1e-05, 'w_std': 0.001}           -1.632444
# 124   {'r_std': 1e-05, 's_std': 1e-05, 'w_std': 1e-05}           -1.632485
# 89   {'r_std': 0.0001, 's_std': 0.001, 'w_std': 1e-05}           -1.637637
#
# [125 rows x 2 columns]

# %% [markdown]
# # Load Trained SR Model

# %%
# Load mappings and original data
fcp = FullContextProcessor(data_fpath="../Data/OConnor2013/ocon-verb-noun-extracted.txt", sep="\t")

# Create mappings
fcp.createTwoWayMap("SOURCE")
fcp.createTwoWayMap("RECEIVER")
fcp.createTwoWayMap("WORD")
fcp.convertColToIdx("SOURCE")
fcp.convertColToIdx("RECEIVER")
fcp.convertColToIdx("WORD")

# %%
# Load model
model = SourceReceiverModel(s_cnt=len(fcp.df["SOURCE"].unique()),
                            r_cnt=len(fcp.df["RECEIVER"].unique()),
                            w_cnt=len(fcp.df["WORD"].unique()),
                            K=50)

model.load_state_dict(torch.load("sr-best-20neg-wstd0.001.pt", map_location="cpu"))

# %%
# Extract the emebddings into numpy arrays
s_embeds = model.s_embeds.weight.detach().numpy()
r_embeds = model.r_embeds.weight.detach().numpy()
w_embeds = model.w_embeds.weight.detach().numpy()

# %% [markdown]
# # Word and SR Tensorflow projection generation

# %%
# Write word vectors out for tensorflow projector
np.savetxt(fname="w_embeds.txt",
           X=w_embeds,
           fmt="%.8f",
           delimiter="\t",)

with open("w_labels.txt", "w") as f:
    for idx, w in fcp.twoway_maps["WORD"]["idx_to_col"].items():
        f.write(str(w) + "\n")

# %%
# Write source vectors out for tensorflow projector
np.savetxt(fname="s_embeds.txt",
           X=s_embeds,
           fmt="%.8f",
           delimiter="\t",)

with open("s_labels.txt", "w") as f:
    for idx, s in fcp.twoway_maps["SOURCE"]["idx_to_col"].items():
        f.write(str(s) + "\n")

# %%
# Write source vectors out for tensorflow projector
np.savetxt(fname="r_embeds.txt",
           X=r_embeds,
           fmt="%.8f",
           delimiter="\t",)

with open("r_labels.txt", "w") as f:
    for idx, s in fcp.twoway_maps["RECEIVER"]["idx_to_col"].items():
        f.write(str(s) + "\n")

# %%
with open("sr_embeds.txt", "w") as embeds_file, open("sr_labels.txt", "w") as labels_file:
    for (s, r), df in fcp.df.groupby(["SOURCE", "RECEIVER"]):
        sr_embed = s_embeds[s, :] + r_embeds[r, :]
        embeds_file.write("\t".join([str(sr_val) for sr_val in sr_embed]) + "\n")
        labels_file.write(
            fcp.twoway_maps["SOURCE"]["idx_to_col"][s] + \
            "-" + \
            fcp.twoway_maps["RECEIVER"]["idx_to_col"][r] + "\n")

# %% [markdown]
# # Word analysis per SR pair

# %%
for (s, r), df in fcp.df.groupby(["SOURCE", "RECEIVER"]):
    print(fcp.twoway_maps["SOURCE"]["idx_to_col"][s], fcp.twoway_maps["RECEIVER"]["idx_to_col"][r], df.shape[0])
    sr_embed = s_embeds[s, :] + r_embeds[r, :]
    sr_word_prod = np.dot(sr_embed, w_embeds.T)
    print([fcp.twoway_maps["WORD"]["idx_to_col"][word_idx] for word_idx in np.argsort(sr_word_prod)][-5:])
# Out:
# IGOUNO IRQ 5374
# ['last', 'personnel', 'mission', 'Tour', 'Party']
# IGOUNO FRA 630
# ['Russia', 'indict', 'approve', 'schedule', 'comprise']
# IGOUNO USA 2857
# ['need', 'Tour', 'Baghdad', 'Party', 'remind']
# IGOUNO GBR 475
# ['request', 'Party', 'indict', 'Iraq', 'Baghdad']
# IGOUNO ISR 2151
# ['Party', 'killing', 'resolution', 'bombing', 'deplore']
# IGOUNO PSE 1143
# ['roadmap', 'representative', 'Israel', 'deplore', 'envisage']
# IGOUNO DEU 312
# ['include', 'Party', 'interview', 'delegate', 'pipe']
# IGOUNO BIH 1530
# ['Tour', 'Party', 'indict', 'mission', 'peacekeep']
# IGOUNO IND 277
# ['Baghdad', 'deplore', 'approve', 'Trust', 'comprise']
# IGOUNO PRK 958
# ['adopt', 'willingness', 'Republic', 'Korea', 'test']
# IGOUNO CIV 480
# ['authorize', 'mission', 'consultation', 'extend', 'embargo']
# IGOUNO IGOEEC 350
# ['assume', 'comprise', 'act', 'presidency', 'approve']
# IGOUNO SYR 862
# ['Tour', 'Party', 'direct', 'belong', 'implicate']
# IGOUNO CHN 898
# ['Party', 'praise', 'comprise', 'invitation', 'overcome']
# IGOUNO IGONAT 516
# ['invoke', 'Kosovo', 'Party', 'approve', 'administer']
# IGOUNO RUS 559
# ['Tour', 'Party', 'remind', 'overcome', 'comprise']
# IGOUNO TMP 415
# ['indict', 'administer', 'govern', 'annexation', 'administration']
# IGOUNO LBN 1634
# ['assassination', 'set', 'mandate', 'authenticate', 'implicate']
# IGOUNO RWA 698
# ['panel', 'Party', 'president', 'repatriate', 'extend']
# IGOUNO IRN 3154
# ['sanction', 'investigate', 'resolution', 'adopt', 'program']
# IGOUNO SOM 647
# ['scale', 'indict', 'Party', 'pull', 'mandate']
# IGOUNO GRC 571
# ['get', 'write', 'Tour', 'coup', 'Party']
# IGOUNO SRB 1641
# ['Party', 'halt', 'drive', 'run', 'administer']
# IGOUNO AFG 1340
# ['appoint', 'Tour', 'pipe', 'Party', 'extend']
# IGOUNO HTI 490
# ['indict', 'Mission', 'mandate', 'mission', 'extend']
# IGOUNO PAK 560
# ['Tour', 'Party', 'appoint', 'deplore', 'praise']
# IGOUNO AGO 601
# ['repatriation', 'Party', 'rebel', 'appoint', 'extend']
# IGOUNO IDN 572
# ['sponsor', 'recognize', 'indict', 'annexation', 'sovereignty']
# IGOUNO TUR 483
# ['Morocco', 'praise', 'Tour', 'Party', 'caution']
# IGOUNO LBR 513
# ['vote', 'assist', 'impose', 'indict', 'lift']
# IGOUNO SDN 1380
# ['government', 'estimate', 'commend', 'appoint', 'adopt']
# IGOUNO MMR 915
# ['ruler', 'Kyi', 'estimate', 'tighten', 'prisoner']
# IGOUNO HRV 802
# ['envoy', 'indict', 'comprise', 'peacekeeper', 'authority']
# IGOUNO KHM 406
# ['rule', 'comprise', 'appoint', 'belong', 'award']
# IGOUNO BDI 372
# ['panel', 'extend', 'representative', 'vote', 'congratulate']
# IGOUNO COD 652
# ['estimate', 'government', 'name', 'mission', 'appoint']
# IGOUNO KWT 1237
# ['employ', 'Iraq', 'subcontractor', 'impose', 'invasion']
# IGOUNO LBY 700
# ['ban', 'embargo', 'sanction', 'impose', 'lift']
# IGOUNO ETH 332
# ['authorize', 'mandate', 'mission', 'Mission', 'extend']
# IGOUNO CYP 843
# ['delimitation', 'reunite', 'version', 'find', 'reunification']
# IGOUNO ALB 492
# ['end', 'halt', 'crackdown', 'administer', 'run']
# IGOUNO ERI 322
# ['extend', 'monitor', 'mandate', 'sanction', 'appoint']
# IGOUNO KSV 977
# ['status', 'govern', 'administration', 'recommend', 'administer']
# IGOUNO SLE 423
# ['Party', 'vote', 'Baghdad', 'Mission', 'indict']
# IGOUNO COG 585
# ['mission', 'broker', 'cease-fire', 'authorize', 'peacekeeper']
# DEU IRQ 1181
# ['oppose', 'disarmament', 'rebuild', 'declaration', 'opponent']
# DEU FRA 515
# ['spearhead', 'line', 'opponent', 'form', 'lead']
# DEU USA 1277
# ['reservation', 'front', 'Tour', 'Party', 'form']
# DEU ISR 353
# ['last', 'Dollars', 'nation', 'Tour', 'Party']
# DEU IGOUNO 1106
# ['contribute', 'circulate', 'chapter', 'power', 'introduce']
# DEU IGOEEC 1068
# ['Party', 'lead', 'join', 'assume', 'presidency']
# DEU CHN 472
# ['Singapore', 'Morocco', 'Tour', 'Party', 'partner']
# DEU IGONAT 441
# ['block', 'command', 'invoke', 'lead', 'expansion']
# DEU RUS 739
# ['Morocco', 'form', 'opponent', 'Tour', 'Party']
# DEU IRN 831
# ['cover', 'Party', 'standoff', 'spearhead', 'program']
# DEU AFG 718
# ['opponent', 'lead', 'contribute', 'serve', 'soldier']
# DEU TUR 354
# ['Tour', 'Party', 'oppose', 'PKK', 'caution']
# JPN IRQ 1322
# ['Tour', 'rebuild', 'Party', 'abducted', 'dispatch']
# JPN USA 2122
# ['nation', 'Singapore', 'Press', 'Tour', 'Party']
# JPN IGOUNO 714
# ['Tour', 'chapter', 'abide', 'submit', 'Party']
# JPN IND 315
# ['coast', 'Party', 'Trust', 'warship', 'refuel']
# JPN PRK 1612
# ['test', 'donor', 'Republic', 'willingness', 'Korea']
# JPN CHN 1741
# ['apologize', 'Party', 'invitation', 'switch', 'Korea']
# JPN RUS 498
# ['Tour', 'buy', 'customer', 'nation', 'Party']
# JPN KOR 500
# ['Tour', 'Party', 'troops', 'station', 'Korea']
# JPN TWN 294
# ['regard', 'consider', 'kilometre', 'claim', 'switch']
# FRA IRQ 2014
# ['disarmament', 'Tour', 'declaration', 'Party', 'opponent']
# FRA USA 1960
# ['last', 'Dollars', 'Tour', 'balk', 'Party']
# FRA GBR 653
# ['lead', 'balk', 'Party', '_', 'States']
# FRA ISR 724
# ['right', 'resolution', 'Tour', 'Party', 'criticise']
# FRA PSE 391
# ['pullback', 'Tour', 'Party', 'reaffirm', 'Israel']
# FRA DEU 408
# ['Tour', 'Party', '_', 'States', 'Africa']
# FRA BIH 424
# ['republic', 'peacekeep', 'Tour', 'Party', 'serve']
# FRA IGOUNO 2576
# ['chapter', 'circulate', 'submit', 'power', 'introduce']
# FRA CIV 758
# ['embargo', 'station', 'evacuate', 'troops', 'soldier']
# FRA IGOEEC 1509
# ['forefront', 'Party', 'join', 'assume', 'presidency']
# FRA CHN 657
# ['Tour', 'investor', 'Party', 'overcome', 'invitation']
# FRA IGONAT 487
# ['Party', 'lead', 'command', 'invoke', 'expansion']
# FRA RUS 635
# ['forward', 'customer', 'Tour', 'Party', 'overcome']
# FRA LBN 574
# ['assassination', 'broker', 'establish', 'power', 'protect']
# FRA RWA 306
# ['ruler', 'Party', 'panel', 'president', 'broker']
# FRA IRN 795
# ['Tour', 'standoff', 'resolution', 'toughen', 'spearhead']
# FRA AFG 439
# ['contribute', 'serve', 'Tour', 'Party', 'soldier']
# FRA TUR 289
# ['share', 'Party', 'PKK', 'caution', 'protect']
# FRA DZA 382
# ['last', 'Tour', 'Party', 'symbol', 'power']
# PSE USA 1424
# ['Tour', 'ambush', 'challenge', 'Party', 'throw']
# PSE ISR 8284
# ['rise', 'blow', 'Party', 'throw', 'ambush']
# PSE EGY 861
# ['Tour', 'Party', 'brief', 'smuggle', 'summit']
# PSE IGOUNO 398
# ['Dollars', 'Singapore', 'Tour', 'throw', 'Party']
# PSE JOR 278
# ['II', 'Morocco', 'Singapore', 'Party', 'summit']
# USA IRQ 18167
# ['Singapore', 'disarm', 'Tour', 'Party', 'die']
# USA FRA 1427
# ['Press', 'thank', 'Singapore', 'Tour', 'Party']
# USA GBR 1478
# ['_', 'Press', 'Singapore', 'Tour', 'Party']
# USA ISR 4097
# ['last', 'forward', 'right', 'Tour', 'Party']
# USA EGY 891
# ['effort', 'Tour', 'arrive', 'Party', 'summit']
# USA PSE 2692
# ['freeze', 'cut', 'aid', 'Tour', 'Party']
# USA DEU 992
# ['telephone', 'last', '_', 'Tour', 'Party']
# USA BIH 1246
# ['Press', 'Singapore', 'republic', 'Tour', 'Party']
# USA IGOUNO 7190
# ['introduce', 'submit', 'chapter', 'Tour', 'Party']
# USA IND 1440
# ['tread', 'Trust', 'Tour', 'Party', 'ground']
# USA PRK 4205
# ['label', 'willingness', 'blacklist', 'test', 'Republic']
# USA IGOEEC 930
# ['Morocco', 'Tour', 'assume', 'presidency', 'Party']
# USA SYR 2318
# ['Symposium', 'last', 'forward', 'Party', 'Tour']
# USA CHN 4323
# ['Singapore', 'overcome', 'Tour', 'apologize', 'Party']
# USA VNM 761
# ['last', 'designate', 'Party', 'Tour', 'jail']
# USA UKR 421
# ['Press', 'restore', 'Tour', 'Party', 'cut']
# USA IGONAT 1264
# ['invoke', 'Press', 'Tour', 'Party', 'expansion']
# USA RUS 4151
# ['overcome', 'Singapore', 'forward', 'Tour', 'Party']
# USA AUS 401
# ['Tour', 'Party', 'praise', 'aid', 'clear']
# USA LBN 943
# ['Party', 'establish', 'Tour', 'protect', 'Syria']
# USA IRN 6876
# ['Party', 'program', 'cover', 'brand', 'label']
# USA SOM 471
# ['Morocco', 'Tour', 'Singapore', 'encounter', 'Party']
# USA SRB 542
# ['Singapore', 'Tour', 'Party', 'drive', 'bomb']
# USA AFG 3881
# ['Singapore', 'Tour', 'Party', 'shelter', 'crash']
# USA JPN 2167
# ['past', 'Tour', 'Singapore', 'missile', 'Party']
# USA HTI 759
# ['forward', 'land', 'Tour', 'Party', 'divert']
# USA JOR 683
# ['Morocco', 'telephone', 'Party', 'apologize', 'provide']
# USA PAK 2697
# ['ground', 'praise', 'Party', 'haven', 'shelter']
# USA KOR 1493
# ['stand', 'Singapore', 'crash', 'Party', 'Tour']
# USA IDN 700
# ['annexation', 'Party', 'Tour', 'sovereignty', 'recognize']
# USA TUR 1911
# ['Tour', 'Party', 'PKK', 'caution', 'share']
# USA TWN 1193
# ['kilometre', 'switch', 'handle', 'consider', 'regard']
# USA CAN 480
# ['Press', 'Morocco', 'Tour', 'Party', 'apologize']
# USA CUB 1293
# ['Party', 'maintain', 'grant', 'expulsion', 'embargo']
# USA THA 389
# ['effort', 'East', 'Party', 'Tour', 'envoy']
# USA SDN 812
# ['Symposium', 'forward', 'designate', 'Tour', 'Party']
# USA MMR 857
# ['designate', 'Kyi', 'prisoner', 'ruler', 'tighten']
# USA ITA 407
# ['phone', 'Singapore', 'Tour', 'Party', 'crash']
# USA GEO 806
# ['Tour', 'basis', 'inherit', 'jockey', 'repel']
# USA HRV 347
# ['divide', 'Singapore', 'Tour', 'Party', 'authority']
# USA SAU 1228
# ['last', 'East', 'Party', 'foreigner', 'Tour']
# USA KWT 934
# ['invade', 'crash', 'invasion', 'subcontractor', 'employ']
# USA LBY 844
# ['Singapore', 'sanction', 'Tour', 'lift', 'Party']
# USA COL 711
# ['Party', 'Tour', 'assist', 'provide', 'decertify']
# USA NGA 324
# ['include', 'Party', 'States', 'appoint', '_']
# USA POL 616
# ['install', 'unveil', 'missile', 'base', 'interceptor']
# USA PHL 1180
# ['help', 'transform', 'assist', 'rape', 'train']
# USA VEN 468
# ['last', 'Tour', 'Party', 'ownership', 'buyer']
# USA MEX 491
# ['praise', 'Singapore', 'Tour', 'assist', 'Party']
# USA ESP 351
# ['comprise', 'Singapore', 'include', 'Tour', 'Party']
# USA CZE 456
# ['place', 'install', 'system', 'unit', 'base']
# USA KEN 434
# ['Party', 'postpone', 'embassy', 'cancel', 'caution']
# USA KSV 667
# ['Party', 'Tour', 'statehood', 'declaration', 'independence']
# CHN IRQ 700
# ['requirement', 'Dollars', 'Singapore', 'Tour', 'Party']
# CHN FRA 747
# ['value', 'rally', 'Party', 'balk', 'States']
# CHN USA 5277
# ['Dollars', 'balk', 'Tour', 'steal', 'Party']
# CHN GBR 639
# ['overtake', 'Press', 'Tour', 'Party', 'States']
# CHN ISR 427
# ['Dollars', 'forward', 'broker', 'Tour', 'Party']
# CHN DEU 538
# ['Tour', 'rally', 'leg', 'Party', 'States']
# CHN IGOUNO 2055
# ['abide', 'implementation', 'chapter', 'Tour', 'Party']
# CHN IND 586
# ['strengthen', 'Tour', 'Trust', 'Party', 'leg']
# CHN PRK 1434
# ['arsenal', 'test', 'Korea', 'willingness', 'Republic']
# CHN IGOEEC 356
# ['steal', 'Tour', 'holder', 'Party', 'collapse']
# CHN VNM 422
# ['Tour', 'Minister', 'Party', 'delegation', 'conclude']
# CHN RUS 1689
# ['States', 'Tour', 'Party', 'industry', 'customer']
# CHN IRN 698
# ['resolve', 'Tour', 'Party', 'collapse', 'entice']
# CHN JPN 2472
# ['Party', 'delegation', 'militarism', 'symbol', 'past']
# CHN PAK 736
# ['Press', 'shelter', 'Tour', 'border', 'Party']
# CHN KOR 957
# ['Tour', 'leg', 'Party', 'Korea', 'delegation']
# CHN CHNTIB 819
# ['revile', 'control', 'Lama', 'govern', 'rule']
# CHN TWN 2763
# ['consider', 'sovereignty', 'switch', 'claim', 'regard']
# CHN THA 477
# ['effort', 'conclude', 'Minister', 'envoy', 'appreciate']
# CHN MMR 473
# ['Kyi', 'ruler', 'visit', 'prisoner', 'tighten']
# CHN HKG 585
# ['claim', 'Party', 'promise', 'guarantee', 'resume']
# RUS IRQ 2252
# ['Party', 'action', 'declaration', 'position', 'oppose']
# RUS FRA 612
# ['plant', 'exporter', 'balk', 'side', 'States']
# RUS USA 4312
# ['exporter', 'balk', 'oppose', 'Party', 'co-sponsor']
# RUS GBR 885
# ['exporter', 'Party', 'side', '_', 'States']
# RUS ISR 682
# ['co-sponsor', 'criticise', 'Party', 'sell', 'right']
# RUS PSE 430
# ['aid', 'pullback', 'Israel', 'roadmap', 'build']
# RUS DEU 605
# ['position', 'Party', '_', 'side', 'States']
# RUS BIH 330
# ['Tour', 'republic', 'Party', 'serve', 'jeopardize']
# RUS IGOUNO 2918
# ['introduce', 'chapter', 'power', 'member', 'veto']
# RUS IND 459
# ['supply', 'Party', 'Trust', 'supplier', 'sell']
# RUS PRK 725
# ['arsenal', 'test', 'reactor', 'supply', 'willingness']
# RUS IGOEEC 847
# ['quartet', 'co-sponsor', 'assume', 'presidency', 'collapse']
# RUS CHN 1178
# ['conclude', 'Tour', 'Party', 'invitation', 'sell']
# RUS UKR 746
# ['Tour', 'Party', 'restore', 'cut', 'States']
# RUS IGONAT 1645
# ['oppose', 'Party', 'Partnership', 'airstrike', 'expansion']
# RUS IRN 2023
# ['sell', 'collapse', 'entice', 'build', 'plant']
# RUS SRB 428
# ['bomb', 'support', 'oppose', 'position', 'drive']
# RUS AFG 350
# ['build', 'sell', 'Singapore', 'Tour', 'Party']
# RUS JPN 672
# ['Party', 'past', 'sink', 'Sea', 'seize']
# RUS TJK 472
# ['Party', 'interest', 'soldier', 'station', 'troops']
# RUS GEO 3192
# ['pour', 'jockey', 'route', 'inherit', 'repel']
# RUS POL 394
# ['install', 'base', 'defens', 'wedge', 'interceptor']
# RUS BLR 254
# ['Cooperation', 'Tour', 'start', 'Party', 'route']
# RUS KSV 622
# ['control', 'oppose', 'statehood', 'independence', 'declaration']
# PAK IRQ 307
# ['war', 'Tour', 'fight', 'Party', 'repulse']
# PAK USA 1953
# ['Press', 'lodge', 'Tour', 'repulse', 'Party']
# PAK GBR 1055
# ['win', 'repulse', 'Party', 'fight', 'gain']
# PAK IGOUNO 510
# ['Tour', 'sideline', 'lodge', 'Party', 'abide']
# PAK IND 2818
# ['Party', 'Trust', 'mass', 'Parliament', 'allegation']
# PAK CHN 465
# ['affair', 'revert', 'Party', 'lodge', 'invitation']
# PAK AFG 1461
# ['border', 'Party', 'regime', 'repulse', 'deploy']
# KOR IRQ 588
# ['Singapore', 'Tour', 'Party', 'medic', 'dispatch']
# KOR USA 1142
# ['Singapore', 'buy', 'Press', 'Tour', 'Party']
# KOR IGOUNO 343
# ['chapter', 'Tour', 'abide', 'implementation', 'Party']
# KOR PRK 1784
# ['ship', 'test', 'Republic', 'Korea', 'willingness']
# KOR CHN 508
# ['leg', 'strengthen', 'Party', 'invitation', 'Korea']
# KOR JPN 710
# ['summon', 'result', 'militarism', 'symbol', 'past']
# IND USA 976
# ['throw', 'need', 'Tour', 'Party', 'backer']
# IND GBR 1042
# ['Party', 'win', 'backer', 'fight', 'gain']
# IND IGOUNO 405
# ['Tour', 'sideline', 'lifting', 'Party', 'backer']
# IND CHN 444
# ['strengthen', 'Tour', 'Party', 'backer', 'invitation']
# IND RUS 356
# ['industry', 'Party', 'worth', 'backer', 'customer']
# IND PAK 5415
# ['blame', 'Tour', 'Party', 'agency', 'two-thirds']
# GRC IGOUNO 512
# ['reunite', 'implementation', 'Party', 'comply', 'veto']
# GRC IGOEEC 953
# ['join', 'assume', 'opt', 'Party', 'presidency']
# GRC MKD 304
# ['Party', 'Tour', 'odds', 'year', 'imply']
# GRC TUR 973
# ['Symposium', 'Singapore', 'last', 'Tour', 'Party']
# GRC CYP 679
# ['independence', 'reunification', 'delimitation', 'guarantor', 'island']
# ISR IRQ 302
# ['battle', 'zone', 'bomb', 'destroy', 'capture']
# ISR USA 2326
# ['cloud', 'Dollars', 'Singapore', 'Tour', 'Party']
# ISR EGY 1486
# ['blessing', 'defeat', 'Party', 'strive', 'summit']
# ISR PSE 29556
# ['offensive', 'confine', 'shell', 'palestinian', 'evacuate']
# ISR IGOUNO 1285
# ['inform', 'Tour', 'ignore', 'Party', 'implement']
# ISR SYR 2794
# ['Tour', 'Party', 'Heights', 'capture', 'seize']
# ISR RUS 306
# ['forward', 'Singapore', 'Tour', 'Party', 'aim']
# ISR LBN 6957
# ['set', 'zone', 'protect', 'strip', 'carve']
# ISR IRN 1135
# ['label', 'suspect', 'punish', 'facility', 'reactor']
# ISR JOR 1277
# ['summit', 'seize', 'Bank', 'annex', 'capture']
# ISR TUR 317
# ['Tour', 'upgrade', 'auspices', 'Party', 'protect']
# IGONAT IRQ 418
# ['Singapore', 'Tour', 'Party', 'strike', 'attack']
# IGONAT USA 624
# ['Press', 'Dollars', 'Singapore', 'Tour', 'Party']
# IGONAT BIH 973
# ['Tour', 'peacekeep', 'Party', 'strike', 'intervene']
# IGONAT IGOUNO 617
# ['Tour', 'Party', 'present', 'sideline', 'authorization']
# IGONAT IGOEEC 375
# ['Dollars', 'Tour', 'presidency', 'Party', 'assume']
# IGONAT RUS 976
# ['last', 'Singapore', 'schedule', 'Tour', 'Party']
# IGONAT MKD 354
# ['Light', 'Dollars', 'Party', 'command', 'Tour']
# IGONAT IRN 462
# ['Party', 'isolate', 'cover', 'program', 'negotiator']
# IGONAT SRB 1184
# ['stop', 'strike', 'drive', 'intervene', 'bomb']
# IGONAT AFG 1069
# ['Force', 'deploy', 'Party', 'soldier', 'wound']
# IGONAT GEO 292
# ['Tour', 'control', 'drive', 'jockey', 'repel']
# IGONAT ALB 571
# ['halt', 'stop', 'bomb', 'run', 'crackdown']
# IGONAT KSV 827
# ['administration', 'declaration', 'administer', 'intervene', 'control']
# IRQ USA 3990
# ['Tour', 'surrender', 'Party', 'challenge', 'pose']
# IRQ GBR 870
# ['footage', 'Press', 'missile', 'Party', 'challenge']
# IRQ ISR 452
# ['attack', 'Party', 'pose', 'ambush', 'fire']
# IRQ IGOUNO 3837
# ['cooperate', 'satisfy', 'precondition', 'breach', 'comply']
# IRQ SYR 541
# ['Tour', 'seize', 'engage', 'blame', 'Party']
# IRQ IRN 968
# ['Tour', 'blame', 'sever', 'Party', 'report']
# IRQ JOR 443
# ['Singapore', 'summit', 'Party', 'capture', 'defect']
# IRQ TUR 1189
# ['Singapore', 'Tour', 'disrupt', 'report', 'Party']
# IRQ SAU 401
# ['behead', 'Tour', 'Party', 'reserve', 'reopen']
# IRQ KWT 1706
# ['plunge', 'Party', 'subcontractor', 'invade', 'invasion']
# SDN IGOUNO 853
# ['abide', 'Party', 'allow', 'accept', 'portray']
# SDN UGA 410
# ['Party', 'consist', 'flee', 'charge', 'Tanzania']
# SDN TCD 413
# ['sever', 'deny', 'blame', 'restore', 'accusation']
# IDN USA 445
# ['Tour', 'extradite', 'setback', 'Party', 'treaty']
# IDN IGOUNO 344
# ['honor', 'abide', 'Party', 'annex', 'setback']
# IDN TMP 1110
# ['ballot', 'holding', 'invade', 'colony', 'annex']
# HKG CHN 461
# ['Party', 'part', 'return', 'affair', 'revert']
# SYR IRQ 707
# ['Tour', 'repulse', 'flow', 'Singapore', 'Party']
# SYR USA 1179
# ['Tour', 'Press', 'pad', 'dominate', 'Party']
# SYR ISR 2014
# ['resignation', 'Tour', 'repulse', 'Party', 'broker']
# SYR PSE 223
# ['dominate', 'situation', 'home', 'powerbroker', 'close']
# SYR IGOUNO 586
# ['submit', 'dominate', 'Party', 'cooperate', 'power']
# SYR LBN 1843
# ['dominate', 'power', 'power-broker', 'broker', 'powerbroker']
# GBR IRQ 5454
# ['abuse', 'patrolling', 'Tour', 'Party', 'enforce']
# GBR FRA 647
# ['Singapore', 'Tour', 'side', 'Party', 'spearhead']
# GBR USA 2088
# ['Press', 'Dollars', 'Singapore', 'Tour', 'Party']
# GBR ISR 543
# ['last', 'forward', 'ally', 'Tour', 'Party']
# GBR PSE 389
# ['Singapore', 'freeze', 'Tour', 'Party', 'cut']
# GBR DEU 286
# ['delegate', 'side', '_', 'Tour', 'Party']
# GBR BIH 355
# ['troops', 'Tuesday', 'republic', 'serve', 'Party']
# GBR IGOUNO 1934
# ['Party', 'breach', 'chapter', 'introduce', 'submit']
# GBR IND 344
# ['Tour', 'Party', 'Trust', 'tread', 'ground']
# GBR IGOEEC 880
# ['Tour', 'join', 'Party', 'assume', 'presidency']
# GBR CHN 680
# ['Tour', 'Party', 'invitation', 'overcome', 'revert']
# GBR IGONAT 256
# ['Tour', 'invoke', 'Wednesday', 'Party', 'command']
# GBR RUS 828
# ['forward', 'Singapore', 'Tour', 'overcome', 'Party']
# GBR IRN 1060
# ['resolution', 'Tour', 'Party', 'standoff', 'spearhead']
# GBR AFG 1058
# ['station', 'Party', 'base', 'troops', 'soldier']
# GBR PAK 477
# ['Singapore', 'Tour', 'Party', 'ground', 'shelter']
# PRK USA 3163
# ['lure', 'normalize', 'intercept', 'shun', 'boycott']
# PRK IGOUNO 804
# ['Party', 'indicate', 'kick', 'demand', 'boycott']
# PRK CHN 578
# ['Party', 'States', 'normalize', 'kick', 'boycott']
# PRK JPN 1566
# ['normalize', 'missile', 'test-fired', 'kidnap', 'admit']
# PRK KOR 1510
# ['boycott', 'agency', 'defect', 'acronym', 'stand']
# EGY IRQ 623
# ['play', 'Tour', 'action', 'Party', 'role']
# EGY USA 837
# ['receive', 'term', 'treaty', 'Party', 'nation']
# EGY ISR 3641
# ['recall', 'nation', 'sign', 'country', 'state']
# EGY PSE 1640
# ['mediator', 'mediate', 'truce', 'Party', 'outbreak']
# EGY IGOUNO 345
# ['Dollars', 'Tour', 'Party', 'role', 'implementation']
# EGY SDN 491
# ['head', 'recall', 'sever', 'stance', 'government']
# IGOEEC IRQ 483
# ['Singapore', 'cloud', 'assess', 'Tour', 'Party']
# IGOEEC FRA 540
# ['clear', 'Austria', 'denial', 'approve', 'Luxembourg']
# IGOEEC USA 1361
# ['approve', 'Austria', 'Tour', 'Luxembourg', 'Party']
# IGOEEC GBR 333
# ['denial', 'Party', 'ban', 'Austria', 'Luxembourg']
# IGOEEC ISR 1063
# ['recognize', 'Tour', 'bombing', 'criticise', 'Party']
# IGOEEC PSE 1100
# ['assess', 'cut', 'aid', 'Israel', 'freeze']
# IGOEEC DEU 352
# ['approve', 'start', 'Austria', 'denial', 'Luxembourg']
# IGOEEC IGOUNO 1103
# ['Party', 'implementation', 'present', 'refer', 'draft']
# IGOEEC CHN 496
# ['start', 'Austria', 'Party', 'Luxembourg', 'overcome']
# IGOEEC IGONAT 224
# ['replace', 'Luxembourg', 'Party', 'approve', 'expansion']
# IGOEEC RUS 1073
# ['Party', 'package', 'objection', 'Luxembourg', 'overcome']
# IGOEEC IRN 1265
# ['suspect', 'cover', 'freeze', 'program', 'negotiator']
# IGOEEC GRC 497
# ['Tour', 'Party', 'Luxembourg', 'admit', 'apply']
# IGOEEC SRB 443
# ['draft', 'drive', 'Tour', 'Party', 'halt']
# IGOEEC TUR 1163
# ['Party', 'caution', 'progress', 'assess', 'PKK']
# IGOEEC MMR 284
# ['Luxembourg', 'Kyi', 'ruler', 'prisoner', 'tighten']
# IGOEEC CYP 448
# ['Republic', 'start', 'decide', 'reunification', 'prefer']
# IGOEEC ESP 293
# ['approve', 'clear', 'Luxembourg', 'comprise', 'denial']
# IGOEEC KSV 446
# ['status', 'recognize', 'statehood', 'declaration', 'independence']
# LBN USA 296
# ['reveal', 'scoff', 'Party', 'complain', 'bow']
# LBN ISR 1614
# ['claim', 'ambush', 'Party', 'wound', 'oust']
# LBN IGOUNO 581
# ['comply', 'breach', 'bow', 'Party', 'complain']
# LBN SYR 594
# ['blame', 'bow', 'reveal', 'leg', 'belong']
# VNM USA 403
# ['Tour', 'earn', 'grant', 'year', 'Party']
# IRN IRQ 1885
# ['Party', 'seize', 'arm', 'patrolling', 'militia']
# IRN FRA 348
# ['Singapore', 'react', 'Tour', 'gesture', 'Party']
# IRN USA 3322
# ['storm', 'react', 'Tour', 'deny', 'Party']
# IRN GBR 723
# ['Press', 'Tour', 'gesture', 'Party', 'footage']
# IRN ISR 1017
# ['recognize', 'Party', 'term', 'withdrawal', 'destruction']
# IRN DEU 386
# ['last', 'Tour', 'minister', 'gesture', 'Party']
# IRN IGOUNO 2582
# ['obey', 'ignore', 'Party', 'defy', 'heed']
# IRN IGOEEC 523
# ['Press', 'shoreline', 'Dollars', 'Tour', 'Party']
# IRN RUS 659
# ['react', 'shoreline', 'pose', 'Tour', 'Party']
# IRN LBN 277
# ['Syria', 'establish', 'influence', 'set', 'assassination']
# IRN AFG 708
# ['arm', 'mass', 'Party', 'seize', 'drug']
# IRN TUR 378
# ['term', 'disrupt', 'Party', 'withdrawal', 'summon']
# THA USA 361
# ['lash', 'pose', 'Party', 'map', 'rely']
# THA MMR 452
# ['ruler', 'Kyi', 'investor', 'tighten', 'prisoner']
# THA KHM 380
# ['Association', 'rule', 'rely', 'downgrade', 'award']
# TUR IRQ 3916
# ['converge', 'Party', 'mass', 'position', 'north']
# TUR USA 1510
# ['Press', 'Dollars', 'converge', 'Tour', 'Party']
# TUR ISR 778
# ['enjoy', 'position', 'Tour', 'converge', 'Party']
# TUR IGOUNO 447
# ['Dollars', 'implementation', 'Tour', 'position', 'Party']
# TUR IGOEEC 1321
# ['Party', 'East', 'ambition', 'candidate', 'join']
# TUR SYR 435
# ['Tour', 'Party', 'Jordan', 'belong', 'converge']
# TUR IGONAT 307
# ['Party', 'expansion', 'Article', 'charter', 'invoke']
# TUR IRN 539
# ['relation', 'Tour', 'Party', 'suspect', 'converge']
# TUR GRC 1146
# ['occupy', 'violate', 'union', 'blueprint', 'coup']
# TUR CYP 903
# ['Republic', 'accession', 'delimitation', 'guarantor', 'island']
# TUR X-TURCYP 704
# ['troops', 'recognize', 'annex', 'maintain', 'Republic']
# AUS IRQ 930
# ['Tour', 'Party', 'invasion', 'personnel', 'contribute']
# AUS USA 847
# ['Press', 'supporter', 'Tour', 'contribute', 'Party']
# AUS IGOUNO 272
# ['breach', 'Tour', 'Party', 'supporter', 'contribute']
# AUS CHN 342
# ['Press', 'Tour', 'strengthen', 'Party', 'invitation']
# AUS IDN 382
# ['assist', 'Tour', 'Party', 'sovereignty', 'annexation']
# HRV BIH 430
# ['Party', 'intervene', 'town', 'republic', 'overrun']
# HRV IGOUNO 366
# ['back', 'surrender', 'Party', 'prevent', 'overrun']
# HRV SRB 227
# ['back', 'intervene', 'outrage', 'declare', 'protectorate']
# TWN USA 592
# ['part', 'split', 'purchase', 'invest', 'lose']
# TWN IGOUNO 283
# ['submit', 'requirement', 'Party', 'part', 'lose']
# TWN CHN 1759
# ['invest', 'lose', 'split', 'part', 'territory']
# CUB USA 936
# ['deny', 'reject', 'Tour', 'Party', 'pose']
# UKR IGONAT 294
# ['Press', 'Party', 'become', 'membership', 'Partnership']
# UKR RUS 706
# ['proposal', 'route', 'buy', 'population', 'rely']
# TMP IDN 258
# ['secede', 'split', 'occupation', 'period', 'break']
# CHNTIB CHN 287
# ['Party', 'overcome', 'crackdown', 'part', 'affair']
# LBY USA 444
# ['surrender', 'Tour', 'lifting', 'Party', 'supervision']
# LBY IGOUNO 380
# ['Party', 'supervision', 'violate', 'letter', 'lifting']
# ESP IRQ 764
# ['Tour', 'Party', 'soldier', 'supporter', 'coalition']
# ESP USA 538
# ['back', 'consultation', 'backer', 'Party', 'supporter']
# ESP IGOUNO 317
# ['power', 'contribute', 'comply', 'supporter', 'submit']
# ESP IGOEEC 416
# ['backer', 'Party', 'holder', 'assume', 'presidency']
# GEO RUS 1660
# ['Tour', 'accusation', 'infuriate', 'Party', 'Sea']
# ITA IRQ 904
# ['contingent', 'troops', 'supporter', 'serve', 'soldier']
# ITA USA 447
# ['need', 'Tour', 'Party', 'serve', 'supporter']
# ITA IGOUNO 208
# ['implementation', 'serve', 'contingent', 'contribute', 'supporter']
# ITA IGOEEC 521
# ['Party', 'reflect', 'supporter', 'assume', 'presidency']
# JOR IRQ 981
# ['Tour', 'dispatch', 'kidnap', 'Party', 'abducted']
# JOR USA 518
# ['treaty', 'side', 'Party', 'receive', 'nation']
# JOR ISR 1864
# ['broker', 'treaty', 'country', 'nation', 'state']
# JOR PSE 598
# ['freeze', 'broker', 'Party', 'kidnap', 'abducted']
# SRB BIH 366
# ['Tour', 'territory', 'republic', 'Party', 'commit']
# SRB IGOUNO 470
# ['Singapore', 'requirement', 'Dollars', 'Tour', 'Party']
# SRB HRV 197
# ['Singapore', 'Party', 'missile', 'break', 'commit']
# SRB KSV 853
# ['recognize', 'control', 'statehood', 'independence', 'declaration']
# MMR THA 349
# ['comprise', 'appreciate', 'ASEAN', 'close', 'envoy']
# MEX USA 730
# ['buy', 'Tour', 'extradite', 'Party', 'sue']
# POL IRQ 1062
# ['interest', 'force', 'soldier', 'represent', 'command']
# POL USA 386
# ['ally', 'Tour', 'command', 'Party', 'represent']
# POL IGOEEC 654
# ['candidate', 'command', 'Party', 'join', 'represent']
# POL IGONAT 365
# ['expansion', 'contribute', 'contender', 'represent', 'command']
# POL RUS 332
# ['last', 'buy', 'Tour', 'Party', 'represent']
# BIH IGOUNO 844
# ['Party', 'surrender', 'write', 'hundred', 'blast']
# BIH IGONAT 227
# ['surrender', 'seize', 'blast', 'retaliate', 'shrug']
# BIH SRB 433
# ['capture', 'stop', 'hide', 'seize', 'sandwich']
# BIH HRV 215
# ['repulse', 'blast', 'retaliate', 'seize', 'sandwich']
# IRL IGOEEC 310
# ['join', 'Party', 'throw', 'assume', 'presidency']
# SAU IRQ 508
# ['fear', 'resolve', 'destabilize', 'Tour', 'Party']
# SAU USA 724
# ['national', 'year', 'Press', 'Tour', 'Party']
# SAU ISR 311
# ['leg', 'Tour', 'normalize', 'Party', 'right']
# KWT IRQ 935
# ['action', 'launchpad', 'disappear', 'War', 'liberate']
# KWT USA 564
# ['pad', 'Party', 'launchpad', 'liberate', 'receive']
# CAN USA 504
# ['Dollars', 'last', 'Tour', 'lose', 'Party']
# CAN AFG 518
# ['rebuild', 'injure', 'fatality', 'soldier', 'lose']
# COL USA 499
# ['Party', 'receive', 'trafficker', 'year', 'extradite']
# AFG USA 618
# ['challenge', 'Party', 'cost', 'need', 'thank']
# AFG PAK 1018
# ['return', 'hide', 'shelter', 'area', 'haven']
# RWA COD 412
# ['camp', 'Party', 'reopen', 'refuge', 'flee']
# RWA COG 559
# ['refuge', 'involvement', 'coalition', 'repatriate', 'intervene']
# UGA SDN 495
# ['sever', 'Tour', 'involvement', 'Party', 'break']
# UGA COG 387
# ['back', 'dispatch', 'intervene', 'involvement', 'coalition']
# PHL IRQ 439
# ['abuse', 'Party', 'attack', 'war', 'expel']
# PHL USA 672
# ['archipelago', 'Tour', 'credit', 'Party', 'get']
# PHL CHN 336
# ['credit', 'overcome', 'get', 'Party', 'archipelago']
# BLR RUS 278
# ['buy', 'pose', 'resume', 'extradite', 'rely']
# MYS USA 400
# ['Dollars', 'Press', 'extradite', 'Tour', 'Party']
# ERI ETH 382
# ['Party', 'win', 'apologize', 'repulse', 'gain']
# ROU IGOEEC 396
# ['Tour', 'Party', 'market', 'hope', 'join']
# BGR IRQ 379
# ['base', 'supporter', 'station', 'lose', 'soldier']
# BGR IGOEEC 410
# ['apply', 'throw', 'communism', 'route', 'join']
# CYP IGOUNO 337
# ['Party', 'submit', 'split', 'implementation', 'reunite']
# CYP IGOEEC 724
# ['Party', 'apply', 'split', 'join', 'start']
# CYP GRC 383
# ['enter', 'apply', 'year', 'split', 'coup']
# CYP TUR 317
# ['start', 'split', 'buy', 'Party', 'protest']
# VEN USA 791
# ['proof', 'Party', 'dislike', 'supplier', 'oil']
# VEN COL 506
# ['intimidate', 'dislike', 'recall', 'border', 'oil']
# KSV IGOUNO 545
# ['breakup', 'Party', 'be', 'seat', 'province']
# KSV SRB 1064
# ['secede', 'declare', 'breakup', 'protectorate', 'province']
# ETH SOM 802
# ['government', 'battle', 'cross', 'intervene', 'rescue']
# ETH ERI 340
# ['opponent', 'cross', 'repatriate', 'panel', 'war']
# NLD IGOEEC 274
# ['candidate', 'East', 'assume', 'holder', 'presidency']
# ALB SRB 288
# ['intervene', 'independence', 'declare', 'bomb', 'claim']
# ALB KSV 157
# ['control', 'statehood', 'clash', 'recognize', 'independence']
# TCD SDN 404
# ['broker', 'government', 'repulse', 'cease-fire', 'break']
# DNK IRQ 506
# ['abuse', 'war', 'station', 'deploy', 'soldier']
