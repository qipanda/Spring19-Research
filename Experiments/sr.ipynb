# %%
# Import relevant modules
% matplotlib notebook

import sys
sys.path.append("../")

from Models.SGNS import SourceReceiverClassifier, SourceReceiverModel
from Preprocessing.FullContextProcessor import FullContextProcessor

import numpy as np
import pandas as pd
import torch
import pickle

# %% [markdown]
# # Std CV Results

# %%
cv_results = pd.read_csv("sr-cv-std-results.txt", sep="\t")
# cv_results.columns
cv_results.loc[:, ["params", "mean_test_Log-Loss"]].sort_values(by="mean_test_Log-Loss", ascending=False)
# Out:
#                                                 params  mean_test_Log-Loss
# 90    {'r_std': 0.0001, 's_std': 0.0001, 'w_std': 0.1}           -1.612109
# 110     {'r_std': 1e-05, 's_std': 0.001, 'w_std': 0.1}           -1.612670
# 20        {'r_std': 0.1, 's_std': 1e-05, 'w_std': 0.1}           -1.612795
# 4         {'r_std': 0.1, 's_std': 0.1, 'w_std': 1e-05}           -1.612898
# 25         {'r_std': 0.01, 's_std': 0.1, 'w_std': 0.1}           -1.612898
# 2         {'r_std': 0.1, 's_std': 0.1, 'w_std': 0.001}           -1.612919
# 70      {'r_std': 0.001, 's_std': 1e-05, 'w_std': 0.1}           -1.613127
# 55       {'r_std': 0.001, 's_std': 0.01, 'w_std': 0.1}           -1.613272
# 80      {'r_std': 0.0001, 's_std': 0.01, 'w_std': 0.1}           -1.614103
# 76      {'r_std': 0.0001, 's_std': 0.1, 'w_std': 0.01}           -1.614394
# 104     {'r_std': 1e-05, 's_std': 0.1, 'w_std': 1e-05}           -1.614498
# 18    {'r_std': 0.1, 's_std': 0.0001, 'w_std': 0.0001}           -1.614560
# 5          {'r_std': 0.1, 's_std': 0.01, 'w_std': 0.1}           -1.614622
# 23     {'r_std': 0.1, 's_std': 1e-05, 'w_std': 0.0001}           -1.614726
# 75       {'r_std': 0.0001, 's_std': 0.1, 'w_std': 0.1}           -1.614872
# 0           {'r_std': 0.1, 's_std': 0.1, 'w_std': 0.1}           -1.615038
# 85     {'r_std': 0.0001, 's_std': 0.001, 'w_std': 0.1}           -1.615121
# 26        {'r_std': 0.01, 's_std': 0.1, 'w_std': 0.01}           -1.615266
# 101      {'r_std': 1e-05, 's_std': 0.1, 'w_std': 0.01}           -1.615370
# 45       {'r_std': 0.01, 's_std': 1e-05, 'w_std': 0.1}           -1.615370
# 29       {'r_std': 0.01, 's_std': 0.1, 'w_std': 1e-05}           -1.615432
# 24      {'r_std': 0.1, 's_std': 1e-05, 'w_std': 1e-05}           -1.615474
# 115    {'r_std': 1e-05, 's_std': 0.0001, 'w_std': 0.1}           -1.615869
# 65     {'r_std': 0.001, 's_std': 0.0001, 'w_std': 0.1}           -1.616014
# 1          {'r_std': 0.1, 's_std': 0.1, 'w_std': 0.01}           -1.616118
# 50        {'r_std': 0.001, 's_std': 0.1, 'w_std': 0.1}           -1.616201
# 102     {'r_std': 1e-05, 's_std': 0.1, 'w_std': 0.001}           -1.616471
# 12      {'r_std': 0.1, 's_std': 0.001, 'w_std': 0.001}           -1.616554
# 51       {'r_std': 0.001, 's_std': 0.1, 'w_std': 0.01}           -1.616637
# 60      {'r_std': 0.001, 's_std': 0.001, 'w_std': 0.1}           -1.616866
# ..                                                 ...                 ...
# 117  {'r_std': 1e-05, 's_std': 0.0001, 'w_std': 0.001}           -1.624426
# 78    {'r_std': 0.0001, 's_std': 0.1, 'w_std': 0.0001}           -1.624510
# 59     {'r_std': 0.001, 's_std': 0.01, 'w_std': 1e-05}           -1.624593
# 86    {'r_std': 0.0001, 's_std': 0.001, 'w_std': 0.01}           -1.624738
# 43   {'r_std': 0.01, 's_std': 0.0001, 'w_std': 0.0001}           -1.625049
# 44    {'r_std': 0.01, 's_std': 0.0001, 'w_std': 1e-05}           -1.625195
# 107    {'r_std': 1e-05, 's_std': 0.01, 'w_std': 0.001}           -1.625216
# 93   {'r_std': 0.0001, 's_std': 0.0001, 'w_std': 0....           -1.625236
# 52      {'r_std': 0.001, 's_std': 0.1, 'w_std': 0.001}           -1.625465
# 97   {'r_std': 0.0001, 's_std': 1e-05, 'w_std': 0.001}           -1.625735
# 73   {'r_std': 0.001, 's_std': 1e-05, 'w_std': 0.0001}           -1.625901
# 58    {'r_std': 0.001, 's_std': 0.01, 'w_std': 0.0001}           -1.625943
# 30        {'r_std': 0.01, 's_std': 0.01, 'w_std': 0.1}           -1.626068
# 69   {'r_std': 0.001, 's_std': 0.0001, 'w_std': 1e-05}           -1.626462
# 74    {'r_std': 0.001, 's_std': 1e-05, 'w_std': 1e-05}           -1.626586
# 64    {'r_std': 0.001, 's_std': 0.001, 'w_std': 1e-05}           -1.626649
# 62    {'r_std': 0.001, 's_std': 0.001, 'w_std': 0.001}           -1.626794
# 61     {'r_std': 0.001, 's_std': 0.001, 'w_std': 0.01}           -1.627397
# 99   {'r_std': 0.0001, 's_std': 1e-05, 'w_std': 1e-05}           -1.628331
# 94   {'r_std': 0.0001, 's_std': 0.0001, 'w_std': 1e...           -1.628497
# 88   {'r_std': 0.0001, 's_std': 0.001, 'w_std': 0.0...           -1.628622
# 123  {'r_std': 1e-05, 's_std': 1e-05, 'w_std': 0.0001}           -1.628975
# 119  {'r_std': 1e-05, 's_std': 0.0001, 'w_std': 1e-05}           -1.629245
# 98   {'r_std': 0.0001, 's_std': 1e-05, 'w_std': 0.0...           -1.630741
# 113  {'r_std': 1e-05, 's_std': 0.001, 'w_std': 0.0001}           -1.631385
# 118  {'r_std': 1e-05, 's_std': 0.0001, 'w_std': 0.0...           -1.632049
# 83   {'r_std': 0.0001, 's_std': 0.01, 'w_std': 0.0001}           -1.632174
# 72    {'r_std': 0.001, 's_std': 1e-05, 'w_std': 0.001}           -1.632444
# 124   {'r_std': 1e-05, 's_std': 1e-05, 'w_std': 1e-05}           -1.632485
# 89   {'r_std': 0.0001, 's_std': 0.001, 'w_std': 1e-05}           -1.637637
#
# [125 rows x 2 columns]

# %% [markdown]
# # Load Trained SR Model

# %%
# Load mappings and original data
fcp = FullContextProcessor(data_fpath="../Data/OConnor2013/ocon-verb-noun-extracted.txt", sep="\t")

# Create mappings
fcp.createTwoWayMap("SOURCE")
fcp.createTwoWayMap("RECEIVER")
fcp.createTwoWayMap("WORD")
fcp.convertColToIdx("SOURCE")
fcp.convertColToIdx("RECEIVER")
fcp.convertColToIdx("WORD")

# %%
# Load model
model = SourceReceiverModel(s_cnt=len(fcp.df["SOURCE"].unique()),
                            r_cnt=len(fcp.df["RECEIVER"].unique()),
                            w_cnt=len(fcp.df["WORD"].unique()),
                            K=50)

model.load_state_dict(torch.load("sr-best-20neg-srstd0.1-wstd0.001.pt", map_location="cpu"))

# %%
# Extract the emebddings into numpy arrays
s_embeds = model.s_embeds.weight.detach().numpy()
r_embeds = model.r_embeds.weight.detach().numpy()
w_embeds = model.w_embeds.weight.detach().numpy()

# %% [markdown]
# # Word and SR Tensorflow projection generation

# %%
# Write word vectors out for tensorflow projector
np.savetxt(fname="w_embeds.txt",
           X=w_embeds,
           fmt="%.8f",
           delimiter="\t",)

with open("w_labels.txt", "w") as f:
    for idx, w in fcp.twoway_maps["WORD"]["idx_to_col"].items():
        f.write(str(w) + "\n")

# %%
# Write source vectors out for tensorflow projector
np.savetxt(fname="s_embeds.txt",
           X=s_embeds,
           fmt="%.8f",
           delimiter="\t",)

with open("s_labels.txt", "w") as f:
    for idx, s in fcp.twoway_maps["SOURCE"]["idx_to_col"].items():
        f.write(str(s) + "\n")

# %%
# Write source vectors out for tensorflow projector
np.savetxt(fname="r_embeds.txt",
           X=r_embeds,
           fmt="%.8f",
           delimiter="\t",)

with open("r_labels.txt", "w") as f:
    for idx, s in fcp.twoway_maps["RECEIVER"]["idx_to_col"].items():
        f.write(str(s) + "\n")

# %%
with open("sr_embeds.txt", "w") as embeds_file, open("sr_labels.txt", "w") as labels_file:
    for (s, r), df in fcp.df.groupby(["SOURCE", "RECEIVER"]):
        sr_embed = s_embeds[s, :] + r_embeds[r, :]
        embeds_file.write("\t".join([str(sr_val) for sr_val in sr_embed]) + "\n")
        labels_file.write(
            fcp.twoway_maps["SOURCE"]["idx_to_col"][s] + \
            "-" + \
            fcp.twoway_maps["RECEIVER"]["idx_to_col"][r] + "\n")

# %% [markdown]
# # Word analysis per SR pair

# %%
# Words at least certain count avoiding vectors that haven't been touched
valid_words = (fcp.df["WORD"].value_counts().sort_index() > 0).values

# %%
for (s, r), df in fcp.df.groupby(["SOURCE", "RECEIVER"]):
    print(fcp.twoway_maps["SOURCE"]["idx_to_col"][s], fcp.twoway_maps["RECEIVER"]["idx_to_col"][r], df.shape[0])
    sr_embed = s_embeds[s, :] + r_embeds[r, :]
    sr_word_prod = np.dot(sr_embed, w_embeds.T)
    print([fcp.twoway_maps["WORD"]["idx_to_col"][word_idx] for word_idx in np.argsort(sr_word_prod)][-10:])
# Out:
# IGOUNO IRQ 5374
# ['disarm', 'Dollars', 'mandate', 'bombing', 'Singapore', 'last', 'Tour', 'mission', 'Party', 'impose']
# IGOUNO FRA 630
# ['interview', 'resignation', 'Morocco', 'representative', 'last', 'Singapore', 'Press', 'Dollars', 'Tour', 'Party']
# IGOUNO USA 2857
# ['Singapore', 'Dollars', 'last', 'need', 'Press', 'authorize', 'renew', 'appeal', 'Tour', 'Party']
# IGOUNO GBR 475
# ['Iraq', 'Baghdad', 'resignation', 'Morocco', 'last', 'Press', 'Singapore', 'Dollars', 'Tour', 'Party']
# IGOUNO ISR 2151
# ['persuade', 'Singapore', 'Dollars', 'pass', 'last', 'deplore', 'Tour', 'renew', 'Party', 'bombing']
# IGOUNO PSE 1143
# ['last', 'debate', 'deplore', 'impose', 'roadmap', 'Tour', 'Party', 'representative', 'envisage', 'situation']
# IGOUNO DEU 312
# ['resignation', 'Morocco', 'persuade', 'last', 'Dollars', 'Press', 'Singapore', 'representative', 'Tour', 'Party']
# IGOUNO BIH 1530
# ['forward', 'Symposium', 'resignation', 'Morocco', 'Press', 'Dollars', 'Singapore', 'last', 'Tour', 'Party']
# IGOUNO IND 277
# ['Morocco', 'Dollars', 'Singapore', 'Press', 'last', 'pass', 'Tour', 'Party', 'sanction', 'impose']
# IGOUNO PRK 958
# ['Republic', 'deliver', 'program', 'convene', 'Tour', 'sanction', 'Party', 'test', 'Korea', 'impose']
# IGOUNO CIV 480
# ['Singapore', 'Mission', 'extend', 'recommend', 'renew', 'mission', 'Tour', 'embargo', 'Party', 'mandate']
# IGOUNO IGOEEC 350
# ['Press', 'representative', 'last', 'appeal', 'represent', 'Dollars', 'meeting', 'Union', 'Tour', 'Party']
# IGOUNO SYR 862
# ['Press', 'Dollars', 'last', 'invite', 'renew', 'Tour', 'pass', 'Party', 'belong', 'implicate']
# IGOUNO CHN 898
# ['Tour', 'representative', 'overcome', 'guest', 'Party', 'pass', 'revert', 'invitation', 'return', 'conclude']
# IGOUNO IGONAT 516
# ['Dollars', 'require', 'run', 'Kosovo', 'authorize', 'recommend', 'appeal', 'Tour', 'Party', 'administer']
# IGOUNO RUS 559
# ['Dollars', 'Press', 'representative', 'last', 'interview', 'persuade', 'overcome', 'pass', 'Tour', 'Party']
# IGOUNO TMP 415
# ['Dollars', 'authorize', 'Singapore', 'last', 'Mission', 'recommend', 'sovereignty', 'Tour', 'mandate', 'Party']
# IGOUNO LBN 1634
# ['belong', 'Tour', 'Party', 'mission', 'end', 'peacekeeper', 'recommend', 'set', 'mandate', 'implicate']
# IGOUNO RWA 698
# ['Symposium', 'Press', 'Dollars', 'renew', 'implicate', 'Singapore', 'last', 'mandate', 'Tour', 'Party']
# IGOUNO IRN 3154
# ['negotiator', 'Tour', 'Party', 'pass', 'toughen', 'vote', 'investigate', 'sanction', 'program', 'impose']
# IGOUNO SOM 647
# ['Press', 'mission', 'recommend', 'Dollars', 'Singapore', 'situation', 'last', 'mandate', 'Tour', 'Party']
# IGOUNO GRC 571
# ['cloud', 'Symposium', 'resignation', 'Morocco', 'Singapore', 'last', 'Press', 'Dollars', 'Tour', 'Party']
# IGOUNO SRB 1641
# ['campaign', 'force', 'recommend', 'Tour', 'Party', 'end', 'run', 'drive', 'halt', 'administer']
# IGOUNO AFG 1340
# ['Press', 'Morocco', 'mandate', 'Dollars', 'last', 'Singapore', 'mission', 'Tour', 'Party', 'situation']
# IGOUNO HTI 490
# ['peacekeeper', 'vote', 'authorize', 'Mission', 'extend', 'recommend', 'mission', 'Tour', 'Party', 'mandate']
# IGOUNO PAK 560
# ['Morocco', 'sanction', 'Dollars', 'deplore', 'pass', 'Press', 'Singapore', 'last', 'Tour', 'Party']
# IGOUNO AGO 601
# ['recommend', 'Morocco', 'extend', 'Press', 'Dollars', 'Singapore', 'last', 'mandate', 'Tour', 'Party']
# IGOUNO IDN 572
# ['pass', 'Press', 'Singapore', 'Dollars', 'last', 'recommend', 'recognize', 'Tour', 'Party', 'sovereignty']
# IGOUNO TUR 483
# ['resignation', 'forward', 'Morocco', 'Press', 'Singapore', 'Dollars', 'recommend', 'last', 'Tour', 'Party']
# IGOUNO LBR 513
# ['Press', 'Dollars', 'Singapore', 'renew', 'last', 'embargo', 'mandate', 'Tour', 'Party', 'impose']
# IGOUNO SDN 1380
# ['Dollars', 'Press', 'vote', 'Singapore', 'last', 'pass', 'Tour', 'renew', 'Party', 'sanction']
# IGOUNO MMR 915
# ['leader', 'estimate', 'mandate', 'pass', 'renew', 'Tour', 'embargo', 'Party', 'sanction', 'impose']
# IGOUNO HRV 802
# ['resignation', 'Morocco', 'mandate', 'Press', 'Singapore', 'Dollars', 'last', 'recommend', 'Tour', 'Party']
# IGOUNO KHM 406
# ['recommend', 'Dollars', 'Singapore', 'last', 'mandate', 'award', 'Tour', 'implicate', 'Party', 'belong']
# IGOUNO BDI 372
# ['recommend', 'resignation', 'mandate', 'Morocco', 'Press', 'Dollars', 'Singapore', 'last', 'Tour', 'Party']
# IGOUNO COD 652
# ['Morocco', 'renew', 'Press', 'recommend', 'Dollars', 'Singapore', 'last', 'mandate', 'Tour', 'Party']
# IGOUNO KWT 1237
# ['last', 'Singapore', 'sanction', 'embargo', 'Tour', 'invade', 'Party', 'sovereignty', 'invasion', 'impose']
# IGOUNO LBY 700
# ['last', 'Tour', 'renew', 'pass', 'embargo', 'Party', 'slap', 'lift', 'sanction', 'impose']
# IGOUNO ETH 332
# ['Press', 'recommend', 'Dollars', 'Singapore', 'Mission', 'last', 'vote', 'Tour', 'mandate', 'Party']
# IGOUNO CYP 843
# ['Dollars', 'leader', 'authorize', 'sovereignty', 'mandate', 'persuade', 'Tour', 'Party', 'reunification', 'recommend']
# IGOUNO ALB 492
# ['Tour', 'Party', 'bomb', 'recommend', 'drive', 'crackdown', 'halt', 'end', 'run', 'administer']
# IGOUNO ERI 322
# ['Morocco', 'Press', 'implicate', 'Singapore', 'pass', 'Dollars', 'renew', 'last', 'Tour', 'Party']
# IGOUNO KSV 977
# ['Mission', 'mission', 'situation', 'run', 'Tour', 'peacekeeper', 'Party', 'mandate', 'administer', 'recommend']
# IGOUNO SLE 423
# ['vote', 'Morocco', 'Mission', 'Singapore', 'Dollars', 'last', 'recommend', 'mandate', 'Tour', 'Party']
# IGOUNO COG 585
# ['Press', 'Morocco', 'Singapore', 'Dollars', 'recommend', 'last', 'vote', 'mandate', 'Tour', 'Party']
# DEU IRQ 1181
# ['Dollars', 'miss', 'Singapore', 'opponent', 'Tour', 'rebuild', 'command', 'disarm', 'Party', 'war']
# DEU FRA 515
# ['investor', 'last', 'Morocco', 'Press', 'Singapore', 'Dollars', 'side', 'Tour', 'represent', 'Party']
# DEU USA 1277
# ['shoreline', 'Morocco', 'last', 'Press', 'side', 'Dollars', 'Singapore', 'Tour', 'Party', 'represent']
# DEU ISR 353
# ['Symposium', 'Press', 'Morocco', 'resignation', 'forward', 'last', 'Singapore', 'Dollars', 'Tour', 'Party']
# DEU IGOUNO 1106
# ['breach', 'chapter', 'seek', 'Dollars', 'contributor', 'Tour', 'Party', 'submit', 'introduce', 'circulate']
# DEU IGOEEC 1068
# ['Dollars', 'constitution', 'collapse', 'join', 'Tour', 'Party', 'Union', 'assume', 'presidency', 'represent']
# DEU CHN 472
# ['Singapore', 'invest', 'start', 'Tour', 'partner', 'investor', 'revert', 'invitation', 'Party', 'conclude']
# DEU IGONAT 441
# ['Morocco', 'last', 'Singapore', 'oppose', 'Dollars', 'block', 'Tour', 'Party', 'command', 'represent']
# DEU RUS 739
# ['shoreline', 'Morocco', 'last', 'partner', 'side', 'Press', 'Singapore', 'Dollars', 'Tour', 'Party']
# DEU IRN 831
# ['Tour', 'case', 'negotiator', 'entice', 'spearhead', 'Party', 'partner', 'standoff', 'program', 'toughen']
# DEU AFG 718
# ['contribute', 'Dollars', 'deploy', 'Singapore', 'Tour', 'station', 'Party', 'serve', 'command', 'soldier']
# DEU TUR 354
# ['shoreline', 'partner', 'forward', 'Morocco', 'Press', 'last', 'Dollars', 'Singapore', 'Tour', 'Party']
# JPN IRQ 1322
# ['Symposium', 'forward', 'Press', 'dispatch', 'last', 'rebuild', 'Dollars', 'Singapore', 'Tour', 'Party']
# JPN USA 2122
# ['forward', 'shoreline', 'Morocco', 'last', 'invest', 'Dollars', 'Press', 'Singapore', 'Tour', 'Party']
# JPN IGOUNO 714
# ['implementation', 'breach', 'Press', 'seek', 'Singapore', 'implement', 'Dollars', 'Tour', 'submit', 'Party']
# JPN IND 315
# ['Symposium', 'resignation', 'Morocco', 'forward', 'last', 'Dollars', 'Press', 'Singapore', 'Tour', 'Party']
# JPN PRK 1612
# ['donor', 'ship', 'Tour', 'detect', 'relation', 'Party', 'willingness', 'test', 'Republic', 'Korea']
# JPN CHN 1741
# ['import', 'split', 'investor', 'Tour', 'start', 'invest', 'Party', 'invitation', 'revert', 'conclude']
# JPN RUS 498
# ['forward', 'last', 'Morocco', 'shoreline', 'buy', 'Dollars', 'Press', 'Singapore', 'Tour', 'Party']
# JPN KOR 500
# ['Morocco', 'last', 'stand', 'Press', 'Dollars', 'Singapore', 'Tour', 'Party', 'troops', 'Korea']
# JPN TWN 294
# ['Singapore', 'switch', 'Tour', 'supplier', 'consider', 'Party', 'regard', 'view', 'sovereignty', 'claim']
# FRA IRQ 2014
# ['contingent', 'last', 'command', 'Dollars', 'Singapore', 'miss', 'disarm', 'Tour', 'war', 'Party']
# FRA USA 1960
# ['resignation', 'shoreline', 'forward', 'Morocco', 'Press', 'last', 'Singapore', 'Dollars', 'Tour', 'Party']
# FRA GBR 653
# ['forward', 'resignation', '_', 'last', 'Morocco', 'Press', 'Singapore', 'Dollars', 'Tour', 'Party']
# FRA ISR 724
# ['broker', 'Morocco', 'resignation', 'forward', 'Singapore', 'last', 'Dollars', 'bombing', 'Tour', 'Party']
# FRA PSE 391
# ['Morocco', 'resignation', 'Press', 'forward', 'last', 'Singapore', 'Dollars', 'Tour', 'Party', 'situation']
# FRA DEU 408
# ['forward', 'resignation', 'Press', 'last', 'Morocco', 'Dollars', 'Singapore', 'investor', 'Tour', 'Party']
# FRA BIH 424
# ['resignation', 'Press', 'Morocco', 'forward', 'last', 'Dollars', 'Singapore', 'serve', 'Tour', 'Party']
# FRA IGOUNO 2576
# ['propose', 'meeting', 'chapter', 'implementation', 'power', 'Tour', 'Party', 'submit', 'introduce', 'circulate']
# FRA CIV 758
# ['Morocco', 'forward', 'last', 'serve', 'Dollars', 'Singapore', 'troops', 'Tour', 'Party', 'deploy']
# FRA IGOEEC 1509
# ['Dollars', 'meeting', 'constitution', 'Tour', 'block', 'represent', 'Party', 'Union', 'assume', 'presidency']
# FRA CHN 657
# ['Singapore', 'start', 'Dollars', 'Tour', 'overcome', 'investor', 'Party', 'invitation', 'revert', 'conclude']
# FRA IGONAT 487
# ['serve', 'Singapore', 'Morocco', 'last', 'oppose', 'Dollars', 'command', 'Tour', 'Party', 'block']
# FRA RUS 635
# ['shoreline', 'Press', 'forward', 'Morocco', 'last', 'Singapore', 'Dollars', 'overcome', 'Tour', 'Party']
# FRA LBN 574
# ['last', 'Dollars', 'set', 'Tour', 'Party', 'assassination', 'protect', 'station', 'power', 'broker']
# FRA RWA 306
# ['Symposium', 'resignation', 'Press', 'Morocco', 'forward', 'last', 'Dollars', 'Singapore', 'Tour', 'Party']
# FRA IRN 795
# ['negotiator', 'case', 'entice', 'facility', 'Tour', 'program', 'spearhead', 'Party', 'standoff', 'toughen']
# FRA AFG 439
# ['last', 'Dollars', 'Singapore', 'situation', 'deploy', 'Tour', 'Party', 'command', 'soldier', 'serve']
# FRA TUR 289
# ['resignation', 'oppose', 'Press', 'forward', 'Morocco', 'last', 'Singapore', 'Dollars', 'Tour', 'Party']
# FRA DZA 382
# ['Symposium', 'resignation', 'Press', 'Morocco', 'forward', 'last', 'Dollars', 'Singapore', 'Tour', 'Party']
# PSE USA 1424
# ['forward', 'resignation', 'shoreline', 'last', 'Dollars', 'Press', 'Singapore', 'Tour', 'denounce', 'Party']
# PSE ISR 8284
# ['last', 'Dollars', 'hurl', 'Singapore', 'Tour', 'fire', 'denounce', 'ambush', 'Party', 'blow']
# PSE EGY 861
# ['shoreline', 'meet', 'last', 'Dollars', 'Press', 'Singapore', 'Tour', 'declare', 'Party', 'summit']
# PSE IGOUNO 398
# ['Press', 'Singapore', 'Dollars', 'Tour', 'submit', 'comply', 'meeting', 'breach', 'Party', 'implement']
# PSE JOR 278
# ['adherence', 'Morocco', 'return', 'last', 'Dollars', 'Press', 'Singapore', 'Tour', 'Party', 'summit']
# USA IRQ 18167
# ['forward', 'last', 'Dollars', 'die', 'Singapore', 'Tour', 'enforce', 'Iran', 'Party', 'disarm']
# USA FRA 1427
# ['shoreline', 'resignation', 'forward', 'last', 'Morocco', 'Press', 'Dollars', 'Singapore', 'Tour', 'Party']
# USA GBR 1478
# ['last', 'Morocco', 'resignation', 'forward', 'Press', 'Dollars', 'Singapore', 'gain', 'Tour', 'Party']
# USA ISR 4097
# ['right', 'Press', 'resignation', 'last', 'forward', 'Dollars', 'bombing', 'Singapore', 'Tour', 'Party']
# USA EGY 891
# ['forward', 'last', 'arrive', 'summit', 'Press', 'Dollars', 'Singapore', 'Tour', 'minister', 'Party']
# USA PSE 2692
# ['Morocco', 'resignation', 'forward', 'last', 'Press', 'Dollars', 'cut', 'Singapore', 'Tour', 'Party']
# USA DEU 992
# ['shoreline', 'resignation', 'forward', 'Morocco', 'last', 'Press', 'Dollars', 'Singapore', 'Tour', 'Party']
# USA BIH 1246
# ['resignation', 'Symposium', 'Morocco', 'Press', 'forward', 'last', 'Dollars', 'Singapore', 'Tour', 'Party']
# USA IGOUNO 7190
# ['Dollars', 'breach', 'press', 'submit', 'Tour', 'refer', 'seek', 'Party', 'introduce', 'circulate']
# USA IND 1440
# ['Symposium', 'Morocco', 'resignation', 'Dollars', 'forward', 'last', 'Press', 'Singapore', 'Tour', 'Party']
# USA PRK 4205
# ['Press', 'Dollars', 'Singapore', 'detect', 'Korea', 'blacklist', 'Tour', 'Republic', 'Party', 'test']
# USA IGOEEC 930
# ['forward', 'last', 'Press', 'presidency', 'Singapore', 'Dollars', 'seek', 'Tour', 'Union', 'Party']
# USA SYR 2318
# ['resignation', 'Morocco', 'Symposium', 'Press', 'Dollars', 'last', 'forward', 'Singapore', 'Tour', 'Party']
# USA CHN 4323
# ['forward', 'last', 'Morocco', 'Dollars', 'Press', 'Singapore', 'Tour', 'revert', 'Party', 'conclude']
# USA VNM 761
# ['Symposium', 'resignation', 'Morocco', 'forward', 'last', 'Press', 'Dollars', 'Singapore', 'Tour', 'Party']
# USA UKR 421
# ['resignation', 'Symposium', 'Morocco', 'last', 'forward', 'Dollars', 'Press', 'Singapore', 'Tour', 'Party']
# USA IGONAT 1264
# ['resignation', 'Morocco', 'forward', 'seek', 'last', 'Press', 'Singapore', 'Dollars', 'Tour', 'Party']
# USA RUS 4151
# ['resignation', 'shoreline', 'Morocco', 'last', 'forward', 'Press', 'Dollars', 'Singapore', 'Tour', 'Party']
# USA AUS 401
# ['Symposium', 'resignation', 'Morocco', 'forward', 'last', 'Press', 'Dollars', 'Singapore', 'Tour', 'Party']
# USA LBN 943
# ['Symposium', 'Press', 'Morocco', 'resignation', 'forward', 'last', 'Dollars', 'Singapore', 'Tour', 'Party']
# USA IRN 6876
# ['case', 'brand', 'label', 'suspect', 'Tour', 'toughen', 'Party', 'sanction', 'program', 'facility']
# USA SOM 471
# ['resignation', 'Morocco', 'Symposium', 'Press', 'forward', 'last', 'Dollars', 'Singapore', 'Tour', 'Party']
# USA SRB 542
# ['Dollars', 'proclaim', 'Singapore', 'independence', 'Tour', 'declare', 'halt', 'bomb', 'Party', 'drive']
# USA AFG 3881
# ['Symposium', 'deploy', 'forward', 'soldier', 'last', 'Dollars', 'Singapore', 'Tour', 'Party', 'base']
# USA JPN 2167
# ['Morocco', 'resignation', 'last', 'forward', 'Press', 'Dollars', 'Singapore', 'admit', 'Tour', 'Party']
# USA HTI 759
# ['resignation', 'Morocco', 'Symposium', 'forward', 'Press', 'last', 'Dollars', 'Singapore', 'Tour', 'Party']
# USA JOR 683
# ['Symposium', 'forward', 'last', 'Morocco', 'Press', 'Dollars', 'Singapore', 'minister', 'Tour', 'Party']
# USA PAK 2697
# ['Symposium', 'resignation', 'Dollars', 'forward', 'last', 'Press', 'haven', 'Singapore', 'Tour', 'Party']
# USA KOR 1493
# ['resignation', 'Symposium', 'Morocco', 'forward', 'last', 'Press', 'Dollars', 'Singapore', 'Tour', 'Party']
# USA IDN 700
# ['resignation', 'Morocco', 'last', 'forward', 'Press', 'Dollars', 'Singapore', 'Tour', 'recognize', 'Party']
# USA TUR 1911
# ['resignation', 'Symposium', 'Morocco', 'Press', 'forward', 'last', 'Dollars', 'Singapore', 'Tour', 'Party']
# USA TWN 1193
# ['sell', 'Singapore', 'sovereignty', 'Tour', 'Party', 'regard', 'view', 'supplier', 'threaten', 'claim']
# USA CAN 480
# ['Symposium', 'resignation', 'Morocco', 'forward', 'last', 'Press', 'Dollars', 'Singapore', 'Tour', 'Party']
# USA CUB 1293
# ['Symposium', 'Morocco', 'resignation', 'forward', 'last', 'Press', 'Dollars', 'Singapore', 'Tour', 'Party']
# USA THA 389
# ['resignation', 'Symposium', 'Morocco', 'forward', 'last', 'Dollars', 'Press', 'Singapore', 'Tour', 'Party']
# USA SDN 812
# ['Morocco', 'resignation', 'Symposium', 'Press', 'Dollars', 'last', 'forward', 'Singapore', 'Tour', 'Party']
# USA MMR 857
# ['Morocco', 'Symposium', 'Press', 'forward', 'Dollars', 'last', 'Singapore', 'Tour', 'Party', 'sanction']
# USA ITA 407
# ['Symposium', 'Morocco', 'resignation', 'forward', 'last', 'Press', 'Dollars', 'Singapore', 'Tour', 'Party']
# USA GEO 806
# ['pour', 'resignation', 'Press', 'forward', 'last', 'Dollars', 'move', 'Singapore', 'Tour', 'Party']
# USA HRV 347
# ['Symposium', 'resignation', 'Morocco', 'Press', 'forward', 'last', 'Dollars', 'Singapore', 'Tour', 'Party']
# USA SAU 1228
# ['resignation', 'Morocco', 'Symposium', 'Press', 'forward', 'last', 'Dollars', 'Singapore', 'Tour', 'Party']
# USA KWT 934
# ['last', 'invasion', 'Dollars', 'Singapore', 'train', 'Tour', 'Party', 'crash', 'impose', 'invade']
# USA LBY 844
# ['Symposium', 'last', 'forward', 'Dollars', 'Press', 'Singapore', 'Tour', 'sanction', 'impose', 'Party']
# USA COL 711
# ['resignation', 'Morocco', 'train', 'forward', 'last', 'Press', 'Dollars', 'Singapore', 'Tour', 'Party']
# USA NGA 324
# ['Symposium', 'Morocco', 'resignation', 'forward', 'Press', 'last', 'Dollars', 'Singapore', 'Tour', 'Party']
# USA POL 616
# ['last', 'forward', 'Press', 'Dollars', 'Singapore', 'Tour', 'plan', 'base', 'Party', 'place']
# USA PHL 1180
# ['crash', 'forward', 'last', 'Press', 'Dollars', 'provide', 'Singapore', 'Tour', 'Party', 'train']
# USA VEN 468
# ['Symposium', 'resignation', 'Morocco', 'forward', 'last', 'Press', 'Dollars', 'Singapore', 'Tour', 'Party']
# USA MEX 491
# ['Symposium', 'resignation', 'Morocco', 'forward', 'last', 'Press', 'Dollars', 'Singapore', 'Tour', 'Party']
# USA ESP 351
# ['Symposium', 'resignation', 'Morocco', 'forward', 'last', 'Press', 'Dollars', 'Singapore', 'Tour', 'Party']
# USA CZE 456
# ['resignation', 'Morocco', 'forward', 'last', 'Press', 'base', 'Dollars', 'Singapore', 'Tour', 'Party']
# USA KEN 434
# ['resignation', 'Morocco', 'Symposium', 'forward', 'Press', 'last', 'Dollars', 'Singapore', 'Tour', 'Party']
# USA KSV 667
# ['Press', 'statehood', 'Morocco', 'forward', 'last', 'Dollars', 'Singapore', 'Tour', 'Party', 'independence']
# CHN IRQ 700
# ['resignation', 'Morocco', 'Symposium', 'forward', 'Press', 'last', 'Dollars', 'Singapore', 'Tour', 'Party']
# CHN FRA 747
# ['Morocco', 'delegation', 'attach', 'Singapore', 'Press', 'Dollars', 'Tour', 'side', 'Party', 'States']
# CHN USA 5277
# ['earn', 'Singapore', 'Dollars', 'Press', 'steal', 'Tour', 'donate', 'side', 'market', 'Party']
# CHN GBR 639
# ['shoreline', 'resignation', 'Morocco', 'side', 'Press', 'Singapore', 'Dollars', 'Tour', 'Party', 'States']
# CHN ISR 427
# ['Morocco', 'shoreline', 'last', 'forward', 'broker', 'Press', 'Singapore', 'Dollars', 'Tour', 'Party']
# CHN DEU 538
# ['conclude', 'attach', 'Press', 'Dollars', 'Singapore', 'delegation', 'side', 'Tour', 'States', 'Party']
# CHN IGOUNO 2055
# ['attend', 'introduce', 'Dollars', 'abstain', 'submit', 'dialogue', 'Tour', 'Party', 'member', 'veto']
# CHN IND 586
# ['Symposium', 'shoreline', 'Morocco', 'forward', 'last', 'Dollars', 'Press', 'Singapore', 'Tour', 'Party']
# CHN PRK 1434
# ['Press', 'Dollars', 'Republic', 'relation', 'Tour', 'scrap', 'willingness', 'test', 'Party', 'Korea']
# CHN IGOEEC 356
# ['assume', 'Dollars', 'veto', 'Tour', 'member', 'represent', 'presidency', 'Party', 'Union', 'collapse']
# CHN VNM 422
# ['Press', 'Dollars', 'Singapore', 'attach', 'appreciate', 'Tour', 'delegation', 'leave', 'Party', 'conclude']
# CHN RUS 1689
# ['industry', 'side', 'delegation', 'States', 'Tour', 'buyer', 'buy', 'Party', 'attach', 'customer']
# CHN IRN 698
# ['Dollars', 'Press', 'view', 'interest', 'facility', 'toughen', 'Tour', 'Party', 'entice', 'collapse']
# CHN JPN 2472
# ['Dollars', 'militarism', 'summon', 'Singapore', 'States', 'past', 'Tour', 'delegation', 'Party', 'symbol']
# CHN PAK 736
# ['resignation', 'Symposium', 'Morocco', 'forward', 'last', 'Dollars', 'Press', 'Singapore', 'Tour', 'Party']
# CHN KOR 957
# ['Morocco', 'tour', 'conclude', 'leave', 'Press', 'Dollars', 'Singapore', 'delegation', 'Tour', 'Party']
# CHN CHNTIB 819
# ['adherence', 'last', 'annex', 'Press', 'Singapore', 'Dollars', 'Tour', 'sovereignty', 'Party', 'rule']
# CHN TWN 2763
# ['Tour', 'sell', 'Party', 'consider', 'threaten', 'supplier', 'sovereignty', 'regard', 'claim', 'view']
# CHN THA 477
# ['Press', 'Singapore', 'leave', 'meet', 'attach', 'Tour', 'appreciate', 'Party', 'delegation', 'conclude']
# CHN MMR 473
# ['Symposium', 'delegation', 'last', 'Press', 'Dollars', 'Singapore', 'leave', 'conclude', 'Tour', 'Party']
# CHN HKG 585
# ['adherence', 'resignation', 'forward', 'Morocco', 'last', 'Press', 'Dollars', 'Singapore', 'Tour', 'Party']
# RUS IRQ 2252
# ['disarm', 'disarmament', 'forward', 'sell', 'last', 'Singapore', 'Dollars', 'Tour', 'Party', 'interest']
# RUS FRA 612
# ['last', 'Morocco', 'Press', 'Singapore', 'Dollars', 'States', 'quartet', 'Tour', 'side', 'Party']
# RUS USA 4312
# ['shrug', 'bristle', 'supplier', 'Dollars', 'side', 'resist', 'Tour', 'co-sponsor', 'Party', 'quartet']
# RUS GBR 885
# ['last', 'Morocco', 'forward', 'Press', 'side', 'Singapore', 'Dollars', 'States', 'Tour', 'Party']
# RUS ISR 682
# ['shoreline', 'Morocco', 'resignation', 'Singapore', 'last', 'forward', 'Dollars', 'Tour', 'right', 'Party']
# RUS PSE 430
# ['forward', 'last', 'build', 'Singapore', 'Dollars', 'roadmap', 'Tour', 'cut', 'situation', 'Party']
# RUS DEU 605
# ['forward', 'Morocco', 'last', 'Press', 'Singapore', 'Dollars', 'States', 'side', 'Tour', 'Party']
# RUS BIH 330
# ['Symposium', 'resignation', 'Press', 'Morocco', 'forward', 'last', 'Singapore', 'Dollars', 'Tour', 'Party']
# RUS IGOUNO 2918
# ['cooperate', 'implementation', 'Tour', 'circulate', 'dialogue', 'abstain', 'member', 'Party', 'quartet', 'veto']
# RUS IND 459
# ['Morocco', 'Press', 'forward', 'Singapore', 'supplier', 'Dollars', 'last', 'sell', 'Tour', 'Party']
# RUS PRK 725
# ['forward', 'deliver', 'last', 'test', 'Dollars', 'Korea', 'reactor', 'Tour', 'willingness', 'Party']
# RUS IGOEEC 847
# ['member', 'Dollars', 'represent', 'expansion', 'Tour', 'veto', 'Party', 'Union', 'quartet', 'collapse']
# RUS CHN 1178
# ['Press', 'enhance', 'Dollars', 'guest', 'supplier', 'Tour', 'invitation', 'Party', 'sell', 'conclude']
# RUS UKR 746
# ['Morocco', 'Press', 'forward', 'last', 'Singapore', 'Dollars', 'sell', 'Tour', 'Party', 'supplier']
# RUS IGONAT 1645
# ['resist', 'last', 'block', 'Dollars', 'Tour', 'member', 'Party', 'oppose', 'quartet', 'expansion']
# RUS IRN 2023
# ['program', 'toughen', 'Party', 'build', 'sell', 'interest', 'reactor', 'entice', 'plant', 'collapse']
# RUS SRB 428
# ['independence', 'Singapore', 'declare', 'Dollars', 'proclaim', 'campaign', 'Tour', 'Party', 'halt', 'drive']
# RUS AFG 350
# ['resignation', 'Press', 'Morocco', 'forward', 'last', 'Dollars', 'Singapore', 'serve', 'Tour', 'Party']
# RUS JPN 672
# ['resignation', 'Morocco', 'shoreline', 'forward', 'Press', 'last', 'Dollars', 'Singapore', 'Tour', 'Party']
# RUS TJK 472
# ['serve', 'Morocco', 'troops', 'forward', 'last', 'Dollars', 'Singapore', 'Tour', 'station', 'Party']
# RUS GEO 3192
# ['basis', 'inherit', 'Tour', 'Party', 'roll', 'route', 'drive', 'move', 'pour', 'repel']
# RUS POL 394
# ['shoreline', 'resignation', 'Morocco', 'Press', 'forward', 'last', 'Singapore', 'Dollars', 'Tour', 'Party']
# RUS BLR 254
# ['Symposium', 'resignation', 'Morocco', 'Press', 'forward', 'last', 'Singapore', 'Dollars', 'Tour', 'Party']
# RUS KSV 622
# ['drive', 'statehood', 'Singapore', 'last', 'Dollars', 'oppose', 'declaration', 'Tour', 'Party', 'independence']
# PAK IRQ 307
# ['last', 'allegation', 'Dollars', 'attack', 'Singapore', 'Tour', 'Party', 'expel', 'mass', 'war']
# PAK USA 1953
# ['shoreline', 'Dollars', 'side', 'Press', 'allegation', 'Singapore', 'lodge', 'Tour', 'Party', 'ally']
# PAK GBR 1055
# ['expel', 'Press', 'Dollars', 'Singapore', 'allegation', 'Tour', 'win', 'Party', 'fight', 'gain']
# PAK IGOUNO 510
# ['implement', 'Press', 'breach', 'Singapore', 'Dollars', 'lodge', 'Tour', 'expel', 'cooperate', 'Party']
# PAK IND 2818
# ['summon', 'Press', 'Singapore', 'Tour', 'expel', 'lodge', 'charge', 'mass', 'Party', 'allegation']
# PAK CHN 465
# ['Press', 'Singapore', 'summon', 'allegation', 'lodge', 'Tour', 'revert', 'conclude', 'invitation', 'Party']
# PAK AFG 1461
# ['terror', 'Dollars', 'Singapore', 'base', 'Tour', 'allegation', 'Party', 'mass', 'border', 'deploy']
# KOR IRQ 588
# ['resignation', 'Symposium', 'forward', 'Press', 'last', 'Dollars', 'war', 'Singapore', 'Tour', 'Party']
# KOR USA 1142
# ['resignation', 'shoreline', 'Morocco', 'last', 'Dollars', 'Press', 'invest', 'Singapore', 'Tour', 'Party']
# KOR IGOUNO 343
# ['seek', 'Singapore', 'implementation', 'cooperate', 'implement', 'Dollars', 'Tour', 'breach', 'submit', 'Party']
# KOR PRK 1784
# ['Dollars', 'Singapore', 'Tour', 'ship', 'detect', 'Party', 'willingness', 'test', 'Republic', 'Korea']
# KOR CHN 508
# ['import', 'Press', 'Singapore', 'guest', 'Tour', 'Party', 'invest', 'invitation', 'revert', 'conclude']
# KOR JPN 710
# ['shoreline', 'Press', 'Dollars', 'past', 'Singapore', 'summon', 'admit', 'Tour', 'Party', 'symbol']
# IND USA 976
# ['forward', 'last', 'buy', 'shoreline', 'Dollars', 'Singapore', 'Press', 'Tour', 'Party', 'need']
# IND GBR 1042
# ['expel', 'backer', 'Press', 'Dollars', 'Singapore', 'Tour', 'Party', 'win', 'fight', 'gain']
# IND IGOUNO 405
# ['implementation', 'Singapore', 'breach', 'Dollars', 'implement', 'expel', 'Tour', 'submit', 'Party', 'need']
# IND CHN 444
# ['Morocco', 'invitation', 'Dollars', 'Singapore', 'Press', 'gain', 'conclude', 'Tour', 'revert', 'Party']
# IND RUS 356
# ['Dollars', 'Press', 'need', 'depend', 'Tour', 'agency', 'expel', 'Party', 'buy', 'customer']
# IND PAK 5415
# ['Dollars', 'rule', 'Press', 'Singapore', 'two-thirds', 'blame', 'Tour', 'expel', 'Party', 'agency']
# GRC IGOUNO 512
# ['comply', 'reject', 'letter', 'implementation', 'Tour', 'breach', 'veto', 'implement', 'Party', 'submit']
# GRC IGOEEC 953
# ['reject', 'Tour', 'collapse', 'represent', 'apply', 'assume', 'Party', 'join', 'Union', 'presidency']
# GRC MKD 304
# ['Symposium', 'Morocco', 'resignation', 'forward', 'last', 'Press', 'Singapore', 'Dollars', 'Tour', 'Party']
# GRC TUR 973
# ['resignation', 'Morocco', 'shoreline', 'forward', 'last', 'Press', 'Singapore', 'Dollars', 'Tour', 'Party']
# GRC CYP 679
# ['resignation', 'last', 'Press', 'Singapore', 'Dollars', 'Tour', 'Party', 'guarantor', 'island', 'independence']
# ISR IRQ 302
# ['zone', 'strike', 'transfer', 'launch', 'pound', 'Party', 'capture', 'bomb', 'shell', 'destroy']
# ISR USA 2326
# ['shoreline', 'resignation', 'forward', 'last', 'Press', 'Dollars', 'Singapore', 'dispute', 'Tour', 'Party']
# ISR EGY 1486
# ['Morocco', 'forward', 'last', 'Press', 'Dollars', 'Singapore', 'return', 'Tour', 'Party', 'summit']
# ISR PSE 29556
# ['tighten', 'demolish', 'Party', 'roll', 'reoccupy', 'clamp', 'blockade', 'shell', 'closure', 'confine']
# ISR IGOUNO 1285
# ['last', 'Press', 'comply', 'Singapore', 'breach', 'Dollars', 'Tour', 'Party', 'violate', 'implement']
# ISR SYR 2794
# ['transfer', 'Dollars', 'Singapore', 'destroy', 'belong', 'Tour', 'Party', 'Heights', 'seize', 'capture']
# ISR RUS 306
# ['reach', 'shoreline', 'last', 'forward', 'Press', 'Dollars', 'summit', 'Singapore', 'Tour', 'Party']
# ISR LBN 6957
# ['aim', 'pound', 'occupation', 'blockade', 'withdraw', 'violate', 'set', 'zone', 'strip', 'carve']
# ISR IRN 1135
# ['Singapore', 'Dollars', 'isolate', 'Tour', 'Party', 'program', 'facility', 'impose', 'reactor', 'suspect']
# ISR JOR 1277
# ['Singapore', 'leg', 'strive', 'Tour', 'return', 'Party', 'annex', 'summit', 'seize', 'capture']
# ISR TUR 317
# ['shoreline', 'Morocco', 'resignation', 'forward', 'last', 'Press', 'Dollars', 'Singapore', 'Tour', 'Party']
# IGONAT IRQ 418
# ['forward', 'launch', 'last', 'Dollars', 'Singapore', 'Tour', 'enforce', 'command', 'Party', 'strike']
# IGONAT USA 624
# ['shoreline', 'resignation', 'forward', 'Morocco', 'last', 'Dollars', 'Press', 'Singapore', 'Tour', 'Party']
# IGONAT BIH 973
# ['Morocco', 'forward', 'command', 'Press', 'last', 'Dollars', 'strike', 'Singapore', 'Tour', 'Party']
# IGONAT IGOUNO 617
# ['Singapore', 'need', 'breach', 'Dollars', 'implement', 'Tour', 'present', 'tell', 'submit', 'Party']
# IGONAT IGOEEC 375
# ['Press', 'Singapore', 'presidency', 'Dollars', 'represent', 'start', 'assume', 'Tour', 'Union', 'Party']
# IGONAT RUS 976
# ['resignation', 'shoreline', 'Morocco', 'forward', 'last', 'Press', 'Dollars', 'Singapore', 'Tour', 'Party']
# IGONAT MKD 354
# ['Symposium', 'resignation', 'forward', 'Morocco', 'Press', 'last', 'Dollars', 'Singapore', 'Tour', 'Party']
# IGONAT IRN 462
# ['Dollars', 'last', 'standoff', 'investigate', 'facility', 'Tour', 'toughen', 'Party', 'program', 'negotiator']
# IGONAT SRB 1184
# ['force', 'administer', 'end', 'Tour', 'run', 'Party', 'strike', 'drive', 'halt', 'bomb']
# IGONAT AFG 1069
# ['last', 'situation', 'serve', 'Dollars', 'Singapore', 'Tour', 'operation', 'Party', 'soldier', 'command']
# IGONAT GEO 292
# ['cloud', 'resignation', 'adherence', 'forward', 'Press', 'last', 'Dollars', 'Singapore', 'Tour', 'Party']
# IGONAT ALB 571
# ['drive', 'Tour', 'administer', 'Party', 'stop', 'crackdown', 'end', 'halt', 'run', 'bomb']
# IGONAT KSV 827
# ['resignation', 'Morocco', 'Press', 'last', 'Dollars', 'Singapore', 'command', 'Tour', 'Party', 'independence']
# IRQ USA 3990
# ['Dollars', 'Press', 'resist', 'surrender', 'Singapore', 'Tour', 'Party', 'denounce', 'challenge', 'pose']
# IRQ GBR 870
# ['shoreline', 'resignation', 'pose', 'Press', 'Dollars', 'Singapore', 'challenge', 'Tour', 'claim', 'Party']
# IRQ ISR 452
# ['resume', 'Dollars', 'Singapore', 'Tour', 'blow', 'ambush', 'denounce', 'Party', 'claim', 'fire']
# IRQ IGOUNO 3837
# ['letter', 'satisfy', 'Tour', 'submit', 'defy', 'Party', 'implement', 'cooperate', 'breach', 'comply']
# IRQ SYR 541
# ['last', 'forward', 'Press', 'Dollars', 'Singapore', 'invite', 'resume', 'Tour', 'Party', 'claim']
# IRQ IRN 968
# ['shoreline', 'facility', 'forward', 'last', 'Dollars', 'Press', 'Singapore', 'accuse', 'Tour', 'Party']
# IRQ JOR 443
# ['shoreline', 'last', 'leg', 'summit', 'Press', 'Dollars', 'Singapore', 'return', 'Tour', 'Party']
# IRQ TUR 1189
# ['forward', 'last', 'shoreline', 'denounce', 'Press', 'pose', 'Dollars', 'Singapore', 'Tour', 'Party']
# IRQ SAU 401
# ['shoreline', 'Symposium', 'resignation', 'forward', 'last', 'Press', 'Dollars', 'Singapore', 'Tour', 'Party']
# IRQ KWT 1706
# ['last', 'Press', 'Dollars', 'Singapore', 'cross', 'sovereignty', 'Tour', 'Party', 'invasion', 'invade']
# SDN IGOUNO 853
# ['defy', 'Singapore', 'comply', 'Dollars', 'breach', 'ignore', 'implement', 'Tour', 'cooperate', 'Party']
# SDN UGA 410
# ['accusation', 'forward', 'shoreline', 'last', 'Dollars', 'deny', 'Press', 'Singapore', 'Tour', 'Party']
# SDN TCD 413
# ['accuse', 'Press', 'Singapore', 'claim', 'Tour', 'flee', 'sever', 'accusation', 'Party', 'deny']
# IDN USA 445
# ['extradite', 'dispute', 'last', 'shoreline', 'Press', 'Dollars', 'treaty', 'Singapore', 'Tour', 'Party']
# IDN IGOUNO 344
# ['last', 'Press', 'breach', 'Singapore', 'annex', 'Dollars', 'submit', 'Tour', 'implement', 'Party']
# IDN TMP 1110
# ['Press', 'recognize', 'Dollars', 'Singapore', 'Tour', 'sovereignty', 'Party', 'invade', 'colony', 'annex']
# HKG CHN 461
# ['start', 'guest', 'split', 'invitation', 'affair', 'Party', 'part', 'conclude', 'return', 'revert']
# SYR IRQ 707
# ['resignation', 'Press', 'forward', 'last', 'Dollars', 'situation', 'Singapore', 'Tour', 'Party', 'war']
# SYR USA 1179
# ['last', 'denounce', 'resist', 'shoreline', 'Singapore', 'Press', 'Dollars', 'dismiss', 'Tour', 'Party']
# SYR ISR 2014
# ['shoreline', 'Press', 'resignation', 'forward', 'last', 'Singapore', 'Dollars', 'broker', 'Tour', 'Party']
# SYR PSE 223
# ['forward', 'resignation', 'last', 'Press', 'demand', 'Dollars', 'Singapore', 'Tour', 'Party', 'situation']
# SYR IGOUNO 586
# ['implementation', 'ignore', 'heed', 'vote', 'breach', 'comply', 'Party', 'implement', 'submit', 'cooperate']
# SYR LBN 1843
# ['situation', 'Party', 'power', 'power-broker', 'withdraw', 'powerbroker', 'belong', 'dominate', 'station', 'broker']
# GBR IRQ 5454
# ['forward', 'command', 'last', 'Dollars', 'Singapore', 'patrol', 'Tour', 'Party', 'disarm', 'enforce']
# GBR FRA 647
# ['resignation', 'forward', 'last', 'Morocco', 'lobby', 'Press', 'Dollars', 'Singapore', 'Tour', 'Party']
# GBR USA 2088
# ['forward', 'Morocco', 'last', 'seek', 'Press', 'Dollars', 'Singapore', 'lobby', 'Tour', 'Party']
# GBR ISR 543
# ['Symposium', 'Morocco', 'resignation', 'Press', 'forward', 'last', 'Dollars', 'Singapore', 'Tour', 'Party']
# GBR PSE 389
# ['cloud', 'Morocco', 'resignation', 'forward', 'Press', 'last', 'Dollars', 'Singapore', 'Tour', 'Party']
# GBR DEU 286
# ['resignation', 'forward', 'last', 'investor', 'Morocco', 'Press', 'Dollars', 'Singapore', 'Tour', 'Party']
# GBR BIH 355
# ['Symposium', 'Morocco', 'Press', 'forward', 'last', 'Dollars', 'troops', 'Singapore', 'Tour', 'Party']
# GBR IGOUNO 1934
# ['implement', 'Dollars', 'Tour', 'chapter', 'Party', 'seek', 'breach', 'circulate', 'submit', 'introduce']
# GBR IND 344
# ['resignation', 'Symposium', 'Morocco', 'forward', 'last', 'Press', 'Dollars', 'Singapore', 'Tour', 'Party']
# GBR IGOEEC 880
# ['Singapore', 'join', 'Dollars', 'Tour', 'seek', 'assume', 'Party', 'Union', 'represent', 'presidency']
# GBR CHN 680
# ['Dollars', 'Singapore', 'overcome', 'return', 'investor', 'invitation', 'Tour', 'Party', 'conclude', 'revert']
# GBR IGONAT 256
# ['member', 'Morocco', 'Press', 'last', 'Singapore', 'seek', 'Dollars', 'command', 'Tour', 'Party']
# GBR RUS 828
# ['Morocco', 'forward', 'last', 'overcome', 'Press', 'Dollars', 'Singapore', 'lobby', 'Tour', 'Party']
# GBR IRN 1060
# ['last', 'case', 'Dollars', 'program', 'facility', 'standoff', 'Tour', 'toughen', 'spearhead', 'Party']
# GBR AFG 1058
# ['station', 'Dollars', 'serve', 'Singapore', 'Tour', 'Party', 'command', 'troops', 'base', 'soldier']
# GBR PAK 477
# ['Symposium', 'Morocco', 'forward', 'Press', 'last', 'Dollars', 'base', 'Singapore', 'Tour', 'Party']
# PRK USA 3163
# ['receive', 'admit', 'normalize', 'refute', 'Tour', 'shun', 'test-fired', 'Party', 'denounce', 'boycott']
# PRK IGOUNO 804
# ['respond', 'notify', 'implement', 'name', 'Party', 'kick', 'threaten', 'submit', 'admit', 'expel']
# PRK CHN 578
# ['admit', 'States', 'Tour', 'test-fired', 'agency', 'normalize', 'Party', 'return', 'kick', 'boycott']
# PRK JPN 1566
# ['Party', 'defect', 'missile', 'splash', 'normalize', 'Sea', 'boycott', 'kidnap', 'test-fired', 'admit']
# PRK KOR 1510
# ['expel', 'defect', 'normalize', 'Party', 'name', 'test-fired', 'boycott', 'agency', 'stand', 'admit']
# EGY IRQ 623
# ['train', 'Symposium', 'forward', 'play', 'last', 'Dollars', 'role', 'Singapore', 'Tour', 'Party']
# EGY USA 837
# ['shoreline', 'Press', 'Singapore', 'Dollars', 'receive', 'Tour', 'treaty', 'country', 'nation', 'Party']
# EGY ISR 3641
# ['nation', 'mediator', 'sign', 'recall', 'Party', 'treaty', 'state', 'mediate', 'broker', 'country']
# EGY PSE 1640
# ['last', 'tour', 'Dollars', 'Singapore', 'invite', 'Tour', 'broker', 'Party', 'situation', 'mediate']
# EGY IGOUNO 345
# ['Morocco', 'last', 'Singapore', 'implementation', 'limit', 'Dollars', 'role', 'Tour', 'submit', 'Party']
# EGY SDN 491
# ['Symposium', 'Press', 'forward', 'Dollars', 'last', 'Singapore', 'Tour', 'recall', 'Party', 'mediate']
# IGOEEC IRQ 483
# ['admit', 'start', 'Press', 'forward', 'last', 'threaten', 'Singapore', 'Dollars', 'Tour', 'Party']
# IGOEEC FRA 540
# ['Singapore', 'Press', 'Dollars', 'Luxembourg', 'replace', 'start', 'Tour', 'Austria', 'Party', '_']
# IGOEEC USA 1361
# ['Morocco', 'last', 'list', 'Singapore', 'Austria', 'replace', 'Press', 'Dollars', 'Tour', 'Party']
# IGOEEC GBR 333
# ['Press', 'Singapore', 'apply', 'Dollars', 'ban', 'replace', 'Tour', 'Austria', '_', 'Party']
# IGOEEC ISR 1063
# ['killing', 'Singapore', 'forward', 'last', 'Dollars', 'draft', 'Tour', 'right', 'bombing', 'Party']
# IGOEEC PSE 1100
# ['debate', 'pullback', 'cut', 'suspend', 'aid', 'Party', 'tighten', 'freeze', 'envisage', 'roadmap']
# IGOEEC DEU 352
# ['last', 'start', 'admit', 'Press', 'Singapore', 'Dollars', 'Tour', 'Austria', '_', 'Party']
# IGOEEC IGOUNO 1103
# ['implement', 'Tour', 'welcome', 'seek', 'Party', 'submit', 'debate', 'circulate', 'draft', 'refer']
# IGOEEC CHN 496
# ['Singapore', 'Dollars', 'Press', 'ban', 'open', 'conclude', 'Tour', 'Party', 'overcome', 'start']
# IGOEEC IGONAT 224
# ['debate', 'Dollars', '_', 'Tour', 'Austria', 'replace', 'Party', 'start', 'draft', 'apply']
# IGOEEC RUS 1073
# ['last', 'Press', 'start', 'Dollars', 'depend', 'Austria', '_', 'Tour', 'Party', 'overcome']
# IGOEEC IRN 1265
# ['refer', 'investigate', 'Party', 'impose', 'sanction', 'toughen', 'freeze', 'case', 'negotiator', 'program']
# IGOEEC GRC 497
# ['open', 'Singapore', 'Press', 'Dollars', 'start', 'Tour', 'Austria', 'Party', 'admit', 'apply']
# IGOEEC SRB 443
# ['Morocco', 'Press', 'forward', 'last', 'Singapore', 'Dollars', 'Tour', 'halt', 'Party', 'independence']
# IGOEEC TUR 1163
# ['Press', 'last', 'draft', 'Dollars', 'admit', 'PKK', 'Austria', 'Tour', 'progress', 'Party']
# IGOEEC MMR 284
# ['Press', 'Dollars', 'last', 'progress', 'ban', 'tighten', 'Tour', 'Party', 'impose', 'sanction']
# IGOEEC CYP 448
# ['Dollars', 'progress', 'Tour', 'Austria', 'independence', 'Party', 'admit', 'open', 'apply', 'start']
# IGOEEC ESP 293
# ['Press', 'Singapore', 'Dollars', 'replace', 'start', 'Tour', 'apply', 'admit', 'Austria', 'Party']
# IGOEEC KSV 446
# ['Morocco', 'Singapore', 'last', 'Dollars', 'draft', 'recognize', 'Tour', 'statehood', 'Party', 'independence']
# LBN USA 296
# ['forward', 'Morocco', 'resignation', 'last', 'shoreline', 'Dollars', 'Press', 'Singapore', 'Tour', 'Party']
# LBN ISR 1614
# ['Press', 'forward', 'last', 'resignation', 'fire', 'Dollars', 'Singapore', 'Tour', 'claim', 'Party']
# LBN IGOUNO 581
# ['Press', 'letter', 'Singapore', 'submit', 'Dollars', 'comply', 'Tour', 'breach', 'implement', 'Party']
# LBN SYR 594
# ['forward', 'last', 'Press', 'Dollars', 'Singapore', 'resume', 'belong', 'Tour', 'Party', 'claim']
# VNM USA 403
# ['forward', 'resignation', 'Morocco', 'last', 'shoreline', 'Dollars', 'Press', 'Singapore', 'Tour', 'Party']
# IRN IRQ 1885
# ['arm', 'patrolling', 'Singapore', 'downfall', 'detain', 'Tour', 'threaten', 'Party', 'interfere', 'militia']
# IRN FRA 348
# ['resignation', 'forward', 'last', 'minister', 'Press', 'shoreline', 'Dollars', 'Singapore', 'Tour', 'Party']
# IRN USA 3322
# ['Dollars', 'Press', 'Singapore', 'shoreline', 'dismiss', 'Tour', 'threat', 'deny', 'slam', 'Party']
# IRN GBR 723
# ['resignation', 'minister', 'last', 'forward', 'shoreline', 'Press', 'Dollars', 'Singapore', 'Tour', 'Party']
# IRN ISR 1017
# ['Singapore', 'Dollars', 'forward', 'condemn', 'slam', 'recognize', 'Tour', 'Party', 'withdrawal', 'destruction']
# IRN DEU 386
# ['resignation', 'forward', 'last', 'Press', 'Dollars', 'shoreline', 'Singapore', 'Tour', 'minister', 'Party']
# IRN IGOUNO 2582
# ['refer', 'remove', 'Dollars', 'Tour', 'comply', 'Party', 'ignore', 'heed', 'defy', 'cooperate']
# IRN IGOEEC 523
# ['shoreline', 'forward', 'collapse', 'Singapore', 'Press', 'last', 'Dollars', 'Tour', 'Union', 'Party']
# IRN RUS 659
# ['last', 'Press', 'Singapore', 'Dollars', 'forward', 'defy', 'shoreline', 'minister', 'Tour', 'Party']
# IRN LBN 277
# ['forward', 'interfere', 'Dollars', 'last', 'Singapore', 'situation', 'assassination', 'Tour', 'broker', 'Party']
# IRN AFG 708
# ['drug', 'last', 'interfere', 'Dollars', 'militia', 'Singapore', 'Tour', 'Party', 'situation', 'border']
# IRN TUR 378
# ['last', 'Dollars', 'Singapore', 'shoreline', 'threat', 'withdrawal', 'Tour', 'minister', 'summon', 'Party']
# THA USA 361
# ['resignation', 'forward', 'Morocco', 'last', 'shoreline', 'Dollars', 'Press', 'Singapore', 'Tour', 'Party']
# THA MMR 452
# ['conclude', 'Morocco', 'forward', 'Symposium', 'last', 'Dollars', 'Press', 'Singapore', 'Tour', 'Party']
# THA KHM 380
# ['resignation', 'forward', 'Morocco', 'shoreline', 'last', 'Press', 'Dollars', 'Singapore', 'Tour', 'Party']
# TUR IRQ 3916
# ['Dollars', 'Singapore', 'position', 'Tour', 'north', 'conduct', 'Party', 'border', 'mass', 'cross']
# TUR USA 1510
# ['ally', 'Press', 'Singapore', 'Dollars', 'pressure', 'dispute', 'Tour', 'open', 'buy', 'Party']
# TUR ISR 778
# ['relation', 'forward', 'last', 'Singapore', 'Dollars', 'pressure', 'recognize', 'ally', 'Tour', 'Party']
# TUR IGOUNO 447
# ['Tour', 'refuse', 'member', 'implement', 'vote', 'press', 'seek', 'cooperate', 'Party', 'violate']
# TUR IGOEEC 1321
# ['realize', 'Dollars', 'join', 'seek', 'Tour', 'open', 'candidate', 'Party', 'Union', 'pressure']
# TUR SYR 435
# ['Republic', 'mass', 'relation', 'belong', 'Tour', 'invite', 'pressure', 'cross', 'Party', 'border']
# TUR IGONAT 307
# ['union', 'refuse', 'seek', 'last', 'Press', 'Singapore', 'Dollars', 'Tour', 'member', 'Party']
# TUR IRN 539
# ['Press', 'last', 'Dollars', 'toughen', 'entice', 'facility', 'Tour', 'relation', 'Party', 'suspect']
# TUR GRC 1146
# ['island', 'Tour', 'violate', 'refuse', 'open', 'Party', 'annex', 'enter', 'union', 'coup']
# TUR CYP 903
# ['union', 'Party', 'refuse', 'declare', 'annex', 'independence', 'open', 'guarantor', 'Republic', 'island']
# TUR X-TURCYP 704
# ['union', 'cross', 'conduct', 'Party', 'recognize', 'annex', 'troops', 'maintain', 'declare', 'Republic']
# AUS IRQ 930
# ['Dollars', 'expel', 'supporter', 'rebuild', 'Singapore', 'command', 'Tour', 'contribute', 'war', 'Party']
# AUS USA 847
# ['buy', 'extradite', 'ally', 'Dollars', 'Press', 'Singapore', 'side', 'Tour', 'represent', 'Party']
# AUS IGOUNO 272
# ['chapter', 'Dollars', 'implementation', 'breach', 'Tour', 'circulate', 'contribute', 'introduce', 'Party', 'submit']
# AUS CHN 342
# ['Singapore', 'guest', 'start', 'investor', 'Tour', 'invest', 'Party', 'conclude', 'invitation', 'revert']
# AUS IDN 382
# ['shoreline', 'forward', 'Morocco', 'last', 'Press', 'Dollars', 'Singapore', 'recognize', 'Tour', 'Party']
# HRV BIH 430
# ['Symposium', 'cloud', 'resignation', 'forward', 'Press', 'last', 'Dollars', 'Singapore', 'Tour', 'Party']
# HRV IGOUNO 366
# ['Press', 'implementation', 'Singapore', 'Dollars', 'comply', 'submit', 'Tour', 'breach', 'implement', 'Party']
# HRV SRB 227
# ['Singapore', 'Tour', 'breakup', 'bomb', 'Party', 'proclaim', 'independence', 'declare', 'halt', 'drive']
# TWN USA 592
# ['Press', 'Dollars', 'Singapore', 'split', 'Tour', 'import', 'Party', 'invest', 'part', 'lose']
# TWN IGOUNO 283
# ['need', 'seek', 'Dollars', 'breach', 'Tour', 'implement', 'Party', 'submit', 'part', 'lose']
# TWN CHN 1759
# ['separate', 'import', 'territory', 'affair', 'ban', 'invest', 'split', 'lose', 'revert', 'part']
# CUB USA 936
# ['resignation', 'forward', 'last', 'denounce', 'shoreline', 'Dollars', 'Press', 'Singapore', 'Tour', 'Party']
# UKR IGONAT 294
# ['shoreline', 'forward', 'Morocco', 'last', 'join', 'Press', 'Singapore', 'Dollars', 'Tour', 'Party']
# UKR RUS 706
# ['Press', 'Dollars', 'Singapore', 'anger', 'depend', 'Tour', 'customer', 'rely', 'Party', 'buy']
# TMP IDN 258
# ['last', 'break', 'Press', 'Dollars', 'Singapore', 'Tour', 'claim', 'sovereignty', 'Party', 'gain']
# CHNTIB CHN 287
# ['conclude', 'Press', 'start', 'Dollars', 'split', 'Singapore', 'Tour', 'Party', 'revert', 'part']
# LBY USA 444
# ['Morocco', 'resignation', 'last', 'shoreline', 'open', 'Dollars', 'Press', 'Singapore', 'Tour', 'Party']
# LBY IGOUNO 380
# ['letter', 'Tour', 'violate', 'cooperate', 'defy', 'Party', 'submit', 'breach', 'implement', 'comply']
# ESP IRQ 764
# ['Dollars', 'supporter', 'contingent', 'Singapore', 'war', 'station', 'Tour', 'command', 'coalition', 'Party']
# ESP USA 538
# ['shoreline', 'Morocco', 'supporter', 'last', 'Press', 'Singapore', 'Dollars', 'Tour', 'Party', 'represent']
# ESP IGOUNO 317
# ['circulate', 'chapter', 'implementation', 'Tour', 'represent', 'implement', 'introduce', 'breach', 'Party', 'submit']
# ESP IGOEEC 416
# ['ratify', 'join', 'Dollars', 'constitution', 'Tour', 'Party', 'Union', 'assume', 'represent', 'presidency']
# GEO RUS 1660
# ['expel', 'Dollars', 'forward', 'shoreline', 'Press', 'Singapore', 'claim', 'Tour', 'detain', 'Party']
# ITA IRQ 904
# ['Tour', 'rebuild', 'supporter', 'station', 'soldier', 'contribute', 'serve', 'Party', 'command', 'war']
# ITA USA 447
# ['shoreline', 'Morocco', 'last', 'Press', 'Dollars', 'Singapore', 'supporter', 'Tour', 'Party', 'represent']
# ITA IGOUNO 208
# ['Dollars', 'breach', 'contingent', 'circulate', 'Tour', 'contributor', 'contribute', 'serve', 'Party', 'submit']
# ITA IGOEEC 521
# ['join', 'Singapore', 'constitution', 'Dollars', 'Tour', 'Party', 'Union', 'assume', 'represent', 'presidency']
# JOR IRQ 981
# ['Press', 'Symposium', 'forward', 'last', 'Dollars', 'Singapore', 'liberate', 'Tour', 'expel', 'Party']
# JOR USA 518
# ['Press', 'Dollars', 'Singapore', 'side', 'receive', 'Tour', 'country', 'nation', 'Party', 'treaty']
# JOR ISR 1864
# ['mediator', 'Tour', 'nation', 'mediate', 'Party', 'state', 'broker', 'sign', 'treaty', 'country']
# JOR PSE 598
# ['forward', 'tour', 'Press', 'last', 'Dollars', 'Singapore', 'mediate', 'Tour', 'situation', 'Party']
# SRB BIH 366
# ['adherence', 'cloud', 'resignation', 'last', 'Press', 'forward', 'Dollars', 'Singapore', 'Tour', 'Party']
# SRB IGOUNO 470
# ['Singapore', 'letter', 'submit', 'ignore', 'comply', 'Dollars', 'Tour', 'breach', 'Party', 'implement']
# SRB HRV 197
# ['Morocco', 'shoreline', 'resignation', 'last', 'forward', 'Press', 'Dollars', 'Singapore', 'Tour', 'Party']
# SRB KSV 853
# ['last', 'Dollars', 'Singapore', 'war', 'Tour', 'recognize', 'declaration', 'statehood', 'Party', 'independence']
# MMR THA 349
# ['Morocco', 'resignation', 'forward', 'shoreline', 'last', 'Dollars', 'Press', 'Singapore', 'Tour', 'Party']
# MEX USA 730
# ['resignation', 'forward', 'Morocco', 'shoreline', 'last', 'Press', 'Dollars', 'Singapore', 'Tour', 'Party']
# POL IRQ 1062
# ['serve', 'force', 'supporter', 'Party', 'disarm', 'soldier', 'represent', 'war', 'contribute', 'command']
# POL USA 386
# ['side', 'Singapore', 'Dollars', 'join', 'contribute', 'Tour', 'supporter', 'ally', 'Party', 'represent']
# POL IGOEEC 654
# ['contributor', 'Tour', 'country', 'Party', 'command', 'Union', 'assume', 'join', 'presidency', 'represent']
# POL IGONAT 365
# ['block', 'Dollars', 'Tour', 'member', 'serve', 'Party', 'contribute', 'join', 'represent', 'command']
# POL RUS 332
# ['Morocco', 'last', 'side', 'Press', 'Singapore', 'Dollars', 'buy', 'Tour', 'Party', 'represent']
# BIH IGOUNO 844
# ['forward', 'last', 'resignation', 'Press', 'breach', 'Singapore', 'Dollars', 'Tour', 'implement', 'Party']
# BIH IGONAT 227
# ['Morocco', 'shoreline', 'resignation', 'forward', 'last', 'Press', 'Singapore', 'Dollars', 'Tour', 'Party']
# BIH SRB 433
# ['forward', 'claim', 'proclaim', 'Dollars', 'Singapore', 'bomb', 'Tour', 'halt', 'Party', 'drive']
# BIH HRV 215
# ['Symposium', 'shoreline', 'resignation', 'forward', 'last', 'Press', 'Dollars', 'Singapore', 'Tour', 'Party']
# IRL IGOEEC 310
# ['Singapore', 'constitution', 'apply', 'Dollars', 'Tour', 'represent', 'Party', 'assume', 'Union', 'presidency']
# SAU IRQ 508
# ['Morocco', 'resignation', 'Symposium', 'Press', 'forward', 'last', 'Dollars', 'Singapore', 'Tour', 'Party']
# SAU USA 724
# ['resignation', 'forward', 'Morocco', 'last', 'shoreline', 'Singapore', 'Dollars', 'Press', 'Tour', 'Party']
# SAU ISR 311
# ['Press', 'last', 'forward', 'Singapore', 'right', 'Dollars', 'broker', 'treaty', 'Tour', 'Party']
# KWT IRQ 935
# ['Press', 'Symposium', 'forward', 'last', 'Dollars', 'Singapore', 'Tour', 'War', 'Party', 'liberate']
# KWT USA 564
# ['side', 'shoreline', 'Dollars', 'Press', 'Singapore', 'nation', 'Tour', 'buy', 'Party', 'treaty']
# CAN USA 504
# ['shoreline', 'forward', 'resignation', 'Morocco', 'last', 'Press', 'Dollars', 'Singapore', 'Tour', 'Party']
# CAN AFG 518
# ['Dollars', 'Singapore', 'suffer', 'Tour', 'troops', 'Party', 'deploy', 'command', 'serve', 'soldier']
# COL USA 499
# ['forward', 'Morocco', 'shoreline', 'last', 'Dollars', 'Press', 'Singapore', 'Tour', 'extradite', 'Party']
# AFG USA 618
# ['forward', 'shoreline', 'resignation', 'last', 'Dollars', 'need', 'Press', 'Singapore', 'Tour', 'Party']
# AFG PAK 1018
# ['shelter', 'hide', 'last', 'Press', 'Singapore', 'Tour', 'area', 'Party', 'haven', 'agency']
# RWA COD 412
# ['withdraw', 'forward', 'Press', 'last', 'Dollars', 'Singapore', 'Tour', 'Party', 'cross', 'flee']
# RWA COG 559
# ['Dollars', 'Singapore', 'intervene', 'pour', 'Tour', 'cross', 'withdraw', 'supporter', 'Party', 'flee']
# UGA SDN 495
# ['Symposium', 'sever', 'Press', 'forward', 'last', 'Dollars', 'expel', 'Singapore', 'Tour', 'Party']
# UGA COG 387
# ['resignation', 'Symposium', 'back', 'Press', 'forward', 'last', 'Dollars', 'Singapore', 'Tour', 'Party']
# PHL IRQ 439
# ['Symposium', 'resignation', 'Press', 'forward', 'last', 'Dollars', 'Singapore', 'Tour', 'Party', 'expel']
# PHL USA 672
# ['resignation', 'forward', 'shoreline', 'Morocco', 'last', 'Dollars', 'Press', 'Singapore', 'Tour', 'Party']
# PHL CHN 336
# ['start', 'Dollars', 'Press', 'invitation', 'Singapore', 'return', 'Tour', 'Party', 'conclude', 'revert']
# BLR RUS 278
# ['Press', 'shoreline', 'Dollars', 'Singapore', 'rely', 'customer', 'depend', 'Tour', 'buy', 'Party']
# MYS USA 400
# ['forward', 'resignation', 'Morocco', 'shoreline', 'last', 'Press', 'Singapore', 'Dollars', 'Tour', 'Party']
# ERI ETH 382
# ['forward', 'resignation', 'Press', 'Dollars', 'Singapore', 'claim', 'Tour', 'Party', 'fight', 'gain']
# ROU IGOEEC 396
# ['Tour', 'start', 'assume', 'hope', 'Party', 'apply', 'represent', 'Union', 'presidency', 'join']
# BGR IRQ 379
# ['last', 'supporter', 'coalition', 'Dollars', 'contribute', 'Singapore', 'soldier', 'Tour', 'command', 'Party']
# BGR IGOEEC 410
# ['Dollars', 'start', 'Tour', 'Party', 'apply', 'assume', 'Union', 'join', 'presidency', 'represent']
# CYP IGOUNO 337
# ['resignation', 'Morocco', 'last', 'implement', 'Press', 'Singapore', 'Dollars', 'Tour', 'submit', 'Party']
# CYP IGOEEC 724
# ['candidate', 'Tour', 'hope', 'Party', 'presidency', 'represent', 'start', 'join', 'Union', 'apply']
# CYP GRC 383
# ['open', 'Press', 'protest', 'Tour', 'remain', 'Party', 'enter', 'apply', 'split', 'coup']
# CYP TUR 317
# ['Morocco', 'forward', 'start', 'shoreline', 'last', 'Dollars', 'Singapore', 'Press', 'Tour', 'Party']
# VEN USA 791
# ['resignation', 'Morocco', 'forward', 'shoreline', 'last', 'Dollars', 'Press', 'Singapore', 'Tour', 'Party']
# VEN COL 506
# ['Morocco', 'resignation', 'forward', 'last', 'Press', 'Dollars', 'Singapore', 'Tour', 'expel', 'Party']
# KSV IGOUNO 545
# ['declare', 'Dollars', 'breach', 'Tour', 'come', 'seat', 'part', 'Party', 'be', 'province']
# KSV SRB 1064
# ['Party', 'independence', 'part', 'protectorate', 'proclaim', 'breakup', 'halt', 'drive', 'declare', 'province']
# ETH SOM 802
# ['deploy', 'Dollars', 'flee', 'government', 'Singapore', 'Tour', 'rescue', 'Party', 'cross', 'intervene']
# ETH ERI 340
# ['Morocco', 'resignation', 'Symposium', 'Press', 'forward', 'last', 'Dollars', 'Singapore', 'Tour', 'Party']
# NLD IGOEEC 274
# ['constitution', 'Press', 'Singapore', 'Dollars', 'represent', 'Tour', 'assume', 'Party', 'Union', 'presidency']
# ALB SRB 288
# ['Singapore', 'independence', 'province', 'breakup', 'Tour', 'halt', 'Party', 'proclaim', 'declare', 'drive']
# ALB KSV 157
# ['forward', 'Press', 'resignation', 'statehood', 'last', 'Singapore', 'Dollars', 'Tour', 'Party', 'independence']
# TCD SDN 404
# ['forward', 'Press', 'last', 'Dollars', 'expel', 'Singapore', 'sever', 'accuse', 'Tour', 'Party']
# DNK IRQ 506
# ['coalition', 'troops', 'supporter', 'contribute', 'Tour', 'command', 'soldier', 'Party', 'station', 'war']
