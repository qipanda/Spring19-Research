# %% [markdown]
# # Load Trained SR Model

# %%
# Import relevant modules
% matplotlib notebook

import sys
sys.path.append("../")

from Models.SGNS import SourceReceiverClassifier, SourceReceiverModel
from Preprocessing.FullContextProcessor import FullContextProcessor

import numpy as np
import pandas as pd
import torch
import pickle

# %%
# Load mappings and original data
fcp = FullContextProcessor(data_fpath="../Data/OConnor2013/ocon-verb-noun-extracted.txt", sep="\t")

# Create mappings
fcp.createTwoWayMap("SOURCE")
fcp.createTwoWayMap("RECEIVER")
fcp.createTwoWayMap("WORD")
fcp.convertColToIdx("SOURCE")
fcp.convertColToIdx("RECEIVER")
fcp.convertColToIdx("WORD")

# Load model
model = SourceReceiverModel(s_cnt=len(fcp.df["SOURCE"].unique()),
                            r_cnt=len(fcp.df["RECEIVER"].unique()),
                            w_cnt=len(fcp.df["WORD"].unique()),
                            K=50)

model.load_state_dict(torch.load("sr-best-20neg.pt", map_location="cpu"))

# %%
# Extract the emebddings into numpy arrays
s_embeds = model.s_embeds.weight.detach().numpy()
r_embeds = model.r_embeds.weight.detach().numpy()
w_embeds = model.w_embeds.weight.detach().numpy()

# %% [markdown]
# # Word and SR Tensorflow projection generation

# %%
# Write word vectors out for tensorflow projector
np.savetxt(fname="w_embeds.txt",
           X=w_embeds,
           fmt="%.8f",
           delimiter="\t",)

with open("w_labels.txt", "w") as f:
    for idx, w in fcp.twoway_maps["WORD"]["idx_to_col"].items():
        f.write(str(w) + "\n")

# %%
# Write source vectors out for tensorflow projector
np.savetxt(fname="s_embeds.txt",
           X=s_embeds,
           fmt="%.8f",
           delimiter="\t",)

with open("s_labels.txt", "w") as f:
    for idx, s in fcp.twoway_maps["SOURCE"]["idx_to_col"].items():
        f.write(str(s) + "\n")

# %%
# Write source vectors out for tensorflow projector
np.savetxt(fname="r_embeds.txt",
           X=r_embeds,
           fmt="%.8f",
           delimiter="\t",)

with open("r_labels.txt", "w") as f:
    for idx, s in fcp.twoway_maps["RECEIVER"]["idx_to_col"].items():
        f.write(str(s) + "\n")

# %%
with open("sr_embeds.txt", "w") as embeds_file, open("sr_labels.txt", "w") as labels_file:
    for (s, r), df in fcp.df.groupby(["SOURCE", "RECEIVER"]):
        sr_embed = s_embeds[s, :] + r_embeds[r, :]
        embeds_file.write("\t".join([str(sr_val) for sr_val in sr_embed]) + "\n")
        labels_file.write(
            fcp.twoway_maps["SOURCE"]["idx_to_col"][s] + \
            "-" + \
            fcp.twoway_maps["RECEIVER"]["idx_to_col"][r] + "\n")

# %% [markdown]
# # Word analysis per SR pair

# %%
# Words at least certain count avoiding vectors that haven't been touched
valid_words = (fcp.df["WORD"].value_counts().sort_index() > 0).values

# %%
for (s, r), df in fcp.df.groupby(["SOURCE", "RECEIVER"]):
    print(fcp.twoway_maps["SOURCE"]["idx_to_col"][s], fcp.twoway_maps["RECEIVER"]["idx_to_col"][r], df.shape[0])
    sr_embed = s_embeds[s, :] + r_embeds[r, :]
    sr_word_prod = np.dot(sr_embed, w_embeds.T)
    print([fcp.twoway_maps["WORD"]["idx_to_col"][word_idx] for word_idx in np.argsort(sr_word_prod)][-5:])
# Out:
# IGOUNO IRQ 5374
# ['requirement', 'Symposium', 'Dollars', 'Tour', 'Party']
# IGOUNO FRA 630
# ['representative', 'envoy', 'Tour', 'persuade', 'schedule']
# IGOUNO USA 2857
# ['Dollars', 'Press', 'appeal', 'Party', 'Tour']
# IGOUNO GBR 475
# ['envoy', 'Party', 'Singapore', 'Tour', 'Baghdad']
# IGOUNO ISR 2151
# ['persuade', 'renew', 'killing', 'Tour', 'Party']
# IGOUNO PSE 1143
# ['situation', 'Press', 'Party', 'representative', 'envisage']
# IGOUNO DEU 312
# ['representative', 'delegate', 'Press', 'pipe', 'schedule']
# IGOUNO BIH 1530
# ['adherence', 'peacekeeper', 'Tour', 'Party', 'party']
# IGOUNO IND 277
# ['mandate', 'slap', 'Symposium', 'Tour', 'appeal']
# IGOUNO PRK 958
# ['refer', 'program', 'adopt', 'inspector', 'test']
# IGOUNO CIV 480
# ['mission', 'party', 'Party', 'peacekeeper', 'embargo']
# IGOUNO IGOEEC 350
# ['act', 'Party', 'Tour', 'appeal', 'meeting']
# IGOUNO SYR 862
# ['concern', 'Party', 'determine', 'direct', 'implicate']
# IGOUNO CHN 898
# ['Singapore', 'representative', 'invitation', 'Tour', 'conclude']
# IGOUNO IGONAT 516
# ['Kosovo', 'archipelago', 'Tour', 'Party', 'administer']
# IGOUNO RUS 559
# ['schedule', 'adherence', 'appeal', 'Tour', 'Party']
# IGOUNO TMP 415
# ['holding', 'annexation', 'Party', 'administration', 'sovereignty']
# IGOUNO LBN 1634
# ['authenticate', 'occupation', 'mandate', 'peacekeeper', 'implicate']
# IGOUNO RWA 698
# ['Symposium', 'spread', 'employer', 'peacekeeper', 'Party']
# IGOUNO IRN 3154
# ['impose', 'adopt', 'sanction', 'investigate', 'program']
# IGOUNO SOM 647
# ['government', 'renew', 'Press', 'Tour', 'Party']
# IGOUNO GRC 571
# ['Party', 'Tour', 'blueprint', 'coup', 'envoy']
# IGOUNO SRB 1641
# ['Party', 'halt', 'hide', 'run', 'administer']
# IGOUNO AFG 1340
# ['party', 'Karzai', 'pipe', 'situation', 'Party']
# IGOUNO HTI 490
# ['Party', 'party', 'Tour', 'mandate', 'peacekeeper']
# IGOUNO PAK 560
# ['Singapore', 'gunfire', 'Party', 'renew', 'Tour']
# IGOUNO AGO 601
# ['requirement', 'peacekeeper', 'mission', 'Party', 'extend']
# IGOUNO IDN 572
# ['elect', 'renew', 'party', 'annexation', 'sovereignty']
# IGOUNO TUR 483
# ['PKK', 'Party', 'caution', 'appeal', 'Tour']
# IGOUNO LBR 513
# ['Party', 'slap', 'hide', 'renew', 'Tour']
# IGOUNO SDN 1380
# ['Tour', 'pass', 'commend', 'Party', 'government']
# IGOUNO MMR 915
# ['renew', 'ruler', 'Tour', 'prisoner', 'estimate']
# IGOUNO HRV 802
# ['spread', 'Party', 'peacekeeper', 'authority', 'extend']
# IGOUNO KHM 406
# ['Press', 'representative', 'rule', 'belong', 'award']
# IGOUNO BDI 372
# ['representative', 'mandate', 'renew', 'party', 'peacekeeper']
# IGOUNO COD 652
# ['mandate', 'cloud', 'Party', 'Press', 'renew']
# IGOUNO KWT 1237
# ['subcontractor', 'Party', 'Symposium', 'impose', 'invasion']
# IGOUNO LBY 700
# ['slap', 'impose', 'lift', 'sanction', 'Party']
# IGOUNO ETH 332
# ['shoreline', 'Mission', 'mandate', 'Tour', 'Party']
# IGOUNO CYP 843
# ['island', 'version', 'foresee', 'reunification', 'persuade']
# IGOUNO ALB 492
# ['Party', 'administer', 'run', 'halt', 'crackdown']
# IGOUNO ERI 322
# ['Spain', 'decision', 'Tour', 'mandate', 'slap']
# IGOUNO KSV 977
# ['estimate', 'administration', 'status', 'recommend', 'administer']
# IGOUNO SLE 423
# ['indict', 'Singapore', 'Press', 'rebel', 'Party']
# IGOUNO COG 585
# ['Singapore', 'party', 'last', 'peacekeeper', 'Party']
# DEU IRQ 1181
# ['Dollars', 'Party', 'disarm', 'disarmament', 'rebuild']
# DEU FRA 515
# ['form', 'Tour', 'Sunday', 'side', 'Cooperation']
# DEU USA 1277
# ['form', 'Sunday', 'Cooperation', 'Dollars', 'Tour']
# DEU ISR 353
# ['Party', 'last', 'ceremony', 'Sunday', 'Tour']
# DEU IGOUNO 1106
# ['push', 'circulate', 'meeting', 'draft', 'contributor']
# DEU IGOEEC 1068
# ['represent', 'helm', 'meeting', 'presidency', 'assume']
# DEU CHN 472
# ['investor', 'invest', 'Singapore', 'invitation', 'Tour']
# DEU IGONAT 441
# ['Tour', 'block', 'contributor', 'invoke', 'command']
# DEU RUS 739
# ['Sunday', 'form', 'partner', 'Dollars', 'Tour']
# DEU IRN 831
# ['program', 'ceremony', 'Symposium', 'spearhead', 'standoff']
# DEU AFG 718
# ['Symposium', 'train', 'situation', 'accident', 'soldier']
# DEU TUR 354
# ['Symposium', 'aspire', 'PKK', 'candidacy', 'Tour']
# JPN IRQ 1322
# ['Singapore', 'troops', 'deploy', 'rebuild', 'Party']
# JPN USA 2122
# ['refuel', 'invest', 'Singapore', 'Tour', 'Party']
# JPN IGOUNO 714
# ['Press', 'promote', 'Singapore', 'contributor', 'Party']
# JPN IND 315
# ['Singapore', 'warship', 'Trust', 'Symposium', 'refuel']
# JPN PRK 1612
# ['last', 'willingness', 'donor', 'test', 'Korea']
# JPN CHN 1741
# ['investor', 'Tour', 'Party', 'Singapore', 'import']
# JPN RUS 498
# ['buy', 'Tour', 'Singapore', 'import', 'Party']
# JPN KOR 500
# ['Singapore', 'deploy', 'Party', 'troops', 'Korea']
# JPN TWN 294
# ['Press', 'Tour', 'statement', 'last', 'handle']
# FRA IRQ 2014
# ['Tour', 'abuse', 'disarmament', 'Party', 'disarm']
# FRA USA 1960
# ['Singapore', 'Dollars', 'Party', 'Cooperation', 'Tour']
# FRA GBR 653
# ['investor', 'lead', 'adhere', 'Singapore', '_']
# FRA ISR 724
# ['ceremony', 'Cooperation', 'last', 'Party', 'Tour']
# FRA PSE 391
# ['draft', 'Press', 'situation', 'last', 'Singapore']
# FRA DEU 408
# ['cloud', 'delegate', 'Africa', '_', 'investor']
# FRA BIH 424
# ['July', 'serve', 'Cooperation', 'Party', 'Tour']
# FRA IGOUNO 2576
# ['introduce', 'veto', 'block', 'meeting', 'draft']
# FRA CIV 758
# ['deploy', 'July', 'Party', 'soldier', 'troops']
# FRA IGOEEC 1509
# ['block', 'constitution', 'assume', 'meeting', 'presidency']
# FRA CHN 657
# ['Singapore', 'conclude', 'Tour', 'investor', 'invitation']
# FRA IGONAT 487
# ['meeting', 'expansion', 'invoke', 'block', 'command']
# FRA RUS 635
# ['_', 'enable', 'Party', 'Cooperation', 'Tour']
# FRA LBN 574
# ['assassination', 'occupation', 'last', 'power', 'protect']
# FRA RWA 306
# ['Symposium', 'Nations', 'abducted', 'Party', 'employer']
# FRA IRN 795
# ['toughen', 'requirement', 'standoff', 'resolution', 'spearhead']
# FRA AFG 439
# ['Karzai', 'deploy', 'command', 'situation', 'soldier']
# FRA TUR 289
# ['aspire', 'candidacy', 'protect', 'PKK', 'Tour']
# FRA DZA 382
# ['Singapore', 'partner', 'leg', 'Dollars', 'symbol']
# PSE USA 1424
# ['denounce', 'Singapore', 'cloud', 'Tour', 'Party']
# PSE ISR 8284
# ['ambush', 'kill', 'throw', 'denounce', 'Party']
# PSE EGY 861
# ['time', 'spokeswoman', 'Party', 'summit', 'brief']
# PSE IGOUNO 398
# ['cloud', 'Press', 'implement', 'meeting', 'Party']
# PSE JOR 278
# ['brief', 'II', 'intimidate', 'time', 'Party']
# USA IRQ 18167
# ['Singapore', 'Iran', 'disarm', 'Tour', 'Party']
# USA FRA 1427
# ['persuade', 'Press', 'Singapore', 'Cooperation', 'Tour']
# USA GBR 1478
# ['Party', 'Tour', 'gain', 'crash', 'Singapore']
# USA ISR 4097
# ['Singapore', 'last', 'right', 'Tour', 'Party']
# USA EGY 891
# ['East', 'minister', 'Tour', 'summit', 'brief']
# USA PSE 2692
# ['last', 'shuttle', 'Party', 'Press', 'Singapore']
# USA DEU 992
# ['accompany', 'division', 'Tour', 'cloud', 'Press']
# USA BIH 1246
# ['cloud', 'Singapore', 'adherence', 'Party', 'Tour']
# USA IGOUNO 7190
# ['push', 'Press', 'veto', 'Party', 'draft']
# USA IND 1440
# ['cherish', 'Singapore', 'Trust', 'Symposium', 'Tour']
# USA PRK 4205
# ['engage', 'detect', 'blacklist', 'label', 'test']
# USA IGOEEC 930
# ['Press', 'forward', 'Cooperation', 'Party', 'Tour']
# USA SYR 2318
# ['concern', 'direct', 'determine', 'last', 'Party']
# USA CHN 4323
# ['conclude', 'collide', 'Party', 'Singapore', 'Tour']
# USA VNM 761
# ['jail', 'Party', 'hopeful', 'investor', 'Tour']
# USA UKR 421
# ['Cooperation', 'Party', 'cut', 'Singapore', 'Tour']
# USA IGONAT 1264
# ['forward', 'expansion', 'command', 'Tour', 'Party']
# USA RUS 4151
# ['haggle', 'adherence', 'Singapore', 'Tour', 'Party']
# USA AUS 401
# ['Dollars', 'Morocco', 'Tour', 'Spain', 'Party']
# USA LBN 943
# ['protect', 'wound', 'murder', 'last', 'Party']
# USA IRN 6876
# ['label', 'brand', 'Party', 'program', 'suspect']
# USA SOM 471
# ['last', 'Press', 'Tour', 'Party', 'group']
# USA SRB 542
# ['independence', 'bomb', 'run', 'Party', 'hide']
# USA AFG 3881
# ['wound', 'deploy', 'operation', 'crash', 'Party']
# USA JPN 2167
# ['sink', 'Press', 'Singapore', 'Tour', 'Party']
# USA HTI 759
# ['hopeful', 'enable', 'Party', 'Singapore', 'Tour']
# USA JOR 683
# ['telephone', 'aspire', 'wrap', 'Party', 'East']
# USA PAK 2697
# ['Singapore', 'shelter', 'Tour', 'area', 'haven']
# USA KOR 1493
# ['adherence', 'Press', 'Tour', 'Party', 'crash']
# USA IDN 700
# ['sovereignty', 'Tour', 'Afghanistan', 'basis', 'recognize']
# USA TUR 1911
# ['Singapore', 'caution', 'list', 'Tour', 'PKK']
# USA TWN 1193
# ['Tour', 'Press', 'supplier', 'sell', 'handle']
# USA CAN 480
# ['hopeful', 'last', 'Tour', 'Singapore', 'Party']
# USA CUB 1293
# ['forward', 'lease', 'Press', 'isolate', 'Bay']
# USA THA 389
# ['renew', 'cloud', 'minister', 'Party', 'Tour']
# USA SDN 812
# ['pinpoint', 'Tour', 'Singapore', 'Sunday', 'Party']
# USA MMR 857
# ['prisoner', 'Press', 'Party', 'ruler', 'Tour']
# USA ITA 407
# ['last', 'Belize', 'law', 'hopeful', 'crash']
# USA GEO 806
# ['jockey', 'pour', 'activity', 'repel', 'basis']
# USA HRV 347
# ['Nations', 'Singapore', 'deploy', 'Party', 'authority']
# USA SAU 1228
# ['Press', 'shut', 'Tour', 'Singapore', 'foreigner']
# USA KWT 934
# ['subcontractor', 'Symposium', 'invasion', 'invade', 'crash']
# USA LBY 844
# ['Tour', 'Press', 'sanction', 'pinpoint', 'Party']
# USA COL 711
# ['Press', 'train', 'decertify', 'crash', 'Party']
# USA NGA 324
# ['Party', 'Singapore', 'abduction', 'cloud', 'wound']
# USA POL 616
# ['missile', 'install', 'base', 'plan', 'interceptor']
# USA PHL 1180
# ['Belize', 'rape', 'Symposium', 'advise', 'train']
# USA VEN 468
# ['Party', 'enable', 'buyer', 'Singapore', 'Tour']
# USA MEX 491
# ['shoreline', 'Morocco', 'Cooperation', 'Nations', 'Press']
# USA ESP 351
# ['pinpoint', 'Dollars', 'Tour', 'shoreline', 'Party']
# USA CZE 456
# ['deploy', 'base', 'install', 'system', 'plan']
# USA KEN 434
# ['Symposium', 'Light', 'Party', 'Tour', 'Singapore']
# USA KSV 667
# ['declaration', 'shuttle', 'status', 'statehood', 'independence']
# CHN IRQ 700
# ['interest', 'last', 'Singapore', 'Tour', 'Party']
# CHN FRA 747
# ['Party', 'Tour', 'Singapore', 'States', 'side']
# CHN USA 5277
# ['side', 'overtake', 'Singapore', 'Party', 'Tour']
# CHN GBR 639
# ['Tour', 'overtake', 'States', 'Party', 'Singapore']
# CHN ISR 427
# ['ceremony', 'Singapore', 'last', 'Tour', 'Party']
# CHN DEU 538
# ['leg', 'Tour', 'rally', 'Party', 'Singapore']
# CHN IGOUNO 2055
# ['Singapore', 'member', 'meeting', 'veto', 'Party']
# CHN IND 586
# ['decade', 'Party', 'Singapore', 'Tour', 'Symposium']
# CHN PRK 1434
# ['ally', 'Tour', 'Party', 'last', 'test']
# CHN IGOEEC 356
# ['last', 'Tour', 'meeting', 'Party', 'collapse']
# CHN VNM 422
# ['investor', 'start', 'Party', 'partner', 'Tour']
# CHN RUS 1689
# ['Tour', 'buyer', 'Party', 'attach', 'customer']
# CHN IRN 698
# ['continue', 'Singapore', 'collapse', 'Party', 'entice']
# CHN JPN 2472
# ['militarism', 'Singapore', 'past', 'symbol', 'Party']
# CHN PAK 736
# ['resignation', 'employer', 'Party', 'Tour', 'Singapore']
# CHN KOR 957
# ['last', 'Singapore', 'delegation', 'Tour', 'Party']
# CHN CHNTIB 819
# ['govern', 'Party', 'march', 'Lama', 'revile']
# CHN TWN 2763
# ['sell', 'sovereignty', 'supplier', 'view', 'regard']
# CHN THA 477
# ['conclude', 'meet', 'Tour', 'Party', 'envoy']
# CHN MMR 473
# ['gunfire', 'Singapore', 'side', 'Party', 'Tour']
# CHN HKG 585
# ['Morocco', 'last', 'Party', 'resume', 'Singapore']
# RUS IRQ 2252
# ['disarm', 'Tour', 'last', 'interest', 'Party']
# RUS FRA 612
# ['Singapore', 'side', 'Party', 'Tour', 'States']
# RUS USA 4312
# ['sell', 'Singapore', 'co-sponsor', 'Party', 'Tour']
# RUS GBR 885
# ['forward', 'Tour', 'States', 'Singapore', 'Party']
# RUS ISR 682
# ['right', 'sell', 'Tour', 'last', 'Party']
# RUS PSE 430
# ['enable', 'envisage', 'last', 'Singapore', 'Party']
# RUS DEU 605
# ['last', 'Arabia', 'Singapore', 'Tour', 'Party']
# RUS BIH 330
# ['Singapore', 'last', 'interest', 'Tour', 'Party']
# RUS IGOUNO 2918
# ['push', 'meeting', 'abstain', 'Party', 'veto']
# RUS IND 459
# ['cherish', 'Party', 'Tour', 'supplier', 'sell']
# RUS PRK 725
# ['test', 'requirement', 'forward', 'Party', 'last']
# RUS IGOEEC 847
# ['co-sponsor', 'last', 'quartet', 'meeting', 'Party']
# RUS CHN 1178
# ['cherish', 'invitation', 'Party', 'Singapore', 'Tour']
# RUS UKR 746
# ['last', 'cut', 'Singapore', 'Tour', 'Party']
# RUS IGONAT 1645
# ['block', 'Partnership', 'command', 'Party', 'expansion']
# RUS IRN 2023
# ['sell', 'Party', 'reactor', 'plant', 'interest']
# RUS SRB 428
# ['Tour', 'hide', 'campaign', 'last', 'Party']
# RUS AFG 350
# ['operation', 'interest', 'enable', 'soldier', 'Party']
# RUS JPN 672
# ['Sea', 'Singapore', 'Tour', 'sink', 'Party']
# RUS TJK 472
# ['Singapore', 'troops', 'soldier', 'station', 'Party']
# RUS GEO 3192
# ['last', 'route', 'basis', 'pour', 'repel']
# RUS POL 394
# ['bone', 'wedge', 'defens', 'plan', 'interceptor']
# RUS BLR 254
# ['shoreline', 'resignation', 'freeze', 'enable', 'Party']
# RUS KSV 622
# ['status', 'statehood', 'Party', 'declaration', 'independence']
# PAK IRQ 307
# ['war', 'Tour', 'mass', 'ally', 'Party']
# PAK USA 1953
# ['side', 'Cooperation', 'emerge', 'Tour', 'ally']
# PAK GBR 1055
# ['Singapore', 'independence', 'win', 'fight', 'gain']
# PAK IGOUNO 510
# ['lifting', 'Cooperation', 'implementation', 'Party', 'seat']
# PAK IND 2818
# ['Trust', 'Symposium', 'mass', 'Tour', 'allegation']
# PAK CHN 465
# ['Party', 'Cooperation', 'Singapore', 'Tour', 'invitation']
# PAK AFG 1461
# ['mass', 'Party', 'terror', 'border', 'deploy']
# KOR IRQ 588
# ['Symposium', 'last', 'Tour', 'medic', 'Party']
# KOR USA 1142
# ['Singapore', 'buy', 'Party', 'invest', 'Tour']
# KOR IGOUNO 343
# ['seat', 'contributor', 'abstain', 'Press', 'Party']
# KOR PRK 1784
# ['activity', 'detect', 'test', 'willingness', 'Korea']
# KOR CHN 508
# ['Singapore', 'Tour', 'invitation', 'invest', 'import']
# KOR JPN 710
# ['Tour', 'militarism', 'Party', 'symbol', 'past']
# IND USA 976
# ['need', 'defend', 'backer', 'Tour', 'Party']
# IND GBR 1042
# ['win', 'Party', 'backer', 'gain', 'fight']
# IND IGOUNO 405
# ['seat', 'July', 'need', 'backer', 'Party']
# IND CHN 444
# ['kick', 'Singapore', 'invitation', 'Tour', 'Party']
# IND RUS 356
# ['worth', 'buyer', 'backer', 'Party', 'customer']
# IND PAK 5415
# ['July', 'Tour', 'Party', 'two-thirds', 'agency']
# GRC IGOUNO 512
# ['block', 'reject', 'Party', 'Press', 'veto']
# GRC IGOEEC 953
# ['constitution', 'opt', 'candidate', 'Union', 'presidency']
# GRC MKD 304
# ['independence', 'Party', 'odds', 'Press', 'imply']
# GRC TUR 973
# ['Tour', 'reject', 'Party', 'prove', 'caution']
# GRC CYP 679
# ['reunification', 'Treaty', 'delimitation', 'island', 'guarantor']
# ISR IRQ 302
# ['destroy', 'bombard', 'free', 'bomb', 'Party']
# ISR USA 2326
# ['Cooperation', 'cloud', 'Press', 'Party', 'Tour']
# ISR EGY 1486
# ['brief', 'head', 'Party', 'summit', 'Tour']
# ISR PSE 29556
# ['Palestinians', 'demolish', 'palestinian', 'Party', 'closure']
# ISR IGOUNO 1285
# ['accept', 'Press', 'violate', 'implement', 'Party']
# ISR SYR 2794
# ['determine', 'capture', 'seize', 'Heights', 'Party']
# ISR RUS 306
# ['adherence', 'cloud', 'aim', 'Tour', 'Party']
# ISR LBN 6957
# ['Party', 'set', 'bombard', 'protect', 'occupation']
# ISR IRN 1135
# ['program', 'punish', 'suspect', 'Party', 'reactor']
# ISR JOR 1277
# ['strive', 'army', 'Bank', 'Party', 'capture']
# ISR TUR 317
# ['PKK', 'protect', 'auspices', 'Party', 'Tour']
# IGONAT IRQ 418
# ['strike', 'Cooperation', 'hole', 'cloud', 'Party']
# IGONAT USA 624
# ['Press', 'Party', 'cloud', 'Cooperation', 'Tour']
# IGONAT BIH 973
# ['command', 'Tour', 'Cooperation', 'cloud', 'Party']
# IGONAT IGOUNO 617
# ['meeting', 'cloud', 'Cooperation', 'Press', 'Party']
# IGONAT IGOEEC 375
# ['cloud', 'Party', 'hand', 'brief', 'Cooperation']
# IGONAT RUS 976
# ['hole', 'schedule', 'Cooperation', 'cloud', 'Party']
# IGONAT MKD 354
# ['suspend', 'hole', 'Party', 'Belize', 'Press']
# IGONAT IRN 462
# ['requirement', 'Symposium', 'Party', 'program', 'negotiator']
# IGONAT SRB 1184
# ['Party', 'cloud', 'end', 'halt', 'run']
# IGONAT AFG 1069
# ['Party', 'Force', 'situation', 'command', 'operation']
# IGONAT GEO 292
# ['move', 'hole', 'repel', 'drive', 'cloud']
# IGONAT ALB 571
# ['run', 'cloud', 'Party', 'crackdown', 'halt']
# IGONAT KSV 827
# ['administer', 'situation', 'statehood', 'mount', 'envision']
# IRQ USA 3990
# ['Dollars', 'behead', 'Tour', 'pose', 'Party']
# IRQ GBR 870
# ['hopeful', 'fight', 'challenge', 'Singapore', 'Party']
# IRQ ISR 452
# ['ambush', 'destruction', 'pose', 'Party', 'fire']
# IRQ IGOUNO 3837
# ['precondition', 'defy', 'breach', 'comply', 'Party']
# IRQ SYR 541
# ['Heights', 'flee', 'last', 'determine', 'Party']
# IRQ IRN 968
# ['flee', 'Dollars', 'Symposium', 'suspect', 'Party']
# IRQ JOR 443
# ['II', 'Belize', 'provider', 'flee', 'Party']
# IRQ TUR 1189
# ['Singapore', 'threat', 'behead', 'Tour', 'Party']
# IRQ SAU 401
# ['foreigner', 'Party', 'Singapore', 'shut', 'behead']
# IRQ KWT 1706
# ['sovereignty', 'Symposium', 'Party', 'invade', 'invasion']
# SDN IGOUNO 853
# ['leak', 'allow', 'last', 'reject', 'package']
# SDN UGA 410
# ['last', 'Tanzania', 'live', 'flee', 'consist']
# SDN TCD 413
# ['Sunday', 'Party', 'last', 'flee', 'accusation']
# IDN USA 445
# ['host', 'Singapore', 'Party', 'treaty', 'Tour']
# IDN IGOUNO 344
# ['Tour', 'Singapore', 'adherence', 'annex', 'Party']
# IDN TMP 1110
# ['Tour', 'Party', 'invade', 'colony', 'annex']
# HKG CHN 461
# ['return', 'Party', 'affair', 'Tour', 'revert']
# SYR IRQ 707
# ['forward', 'home', 'station', 'Symposium', 'Party']
# SYR USA 1179
# ['Tour', 'Party', 'forward', 'reject', 'pad']
# SYR ISR 2014
# ['forward', 'revive', 'demand', 'reject', 'Party']
# SYR PSE 223
# ['forward', 'situation', 'power-broker', 'close', 'home']
# SYR IGOUNO 586
# ['insist', 'Party', 'Press', 'reject', 'power']
# SYR LBN 1843
# ['broker', 'dominate', 'power', 'powerbroker', 'power-broker']
# GBR IRQ 5454
# ['Singapore', 'last', 'Dollars', 'disarm', 'Party']
# GBR FRA 647
# ['Dollars', 'spearhead', 'Press', 'Singapore', 'side']
# GBR USA 2088
# ['Dollars', 'Singapore', 'Party', 'Tour', 'ally']
# GBR ISR 543
# ['Tour', 'Singapore', 'ally', 'last', 'Party']
# GBR PSE 389
# ['forward', 'Party', 'last', 'Press', 'Singapore']
# GBR DEU 286
# ['revise', 'investor', 'bid', 'Press', 'cloud']
# GBR BIH 355
# ['cloud', 'last', 'Dollars', 'troops', 'Party']
# GBR IGOUNO 1934
# ['submit', 'draft', 'meeting', 'contributor', 'introduce']
# GBR IND 344
# ['Dollars', 'unite', 'investor', 'Singapore', 'Symposium']
# GBR IGOEEC 880
# ['last', 'Party', 'assume', 'meeting', 'presidency']
# GBR CHN 680
# ['pay', 'investor', 'revert', 'Singapore', 'invitation']
# GBR IGONAT 256
# ['invoke', 'Press', 'forward', 'Party', 'command']
# GBR RUS 828
# ['spearhead', 'overcome', 'Dollars', 'Singapore', 'Party']
# GBR IRN 1060
# ['Symposium', 'Party', 'standoff', 'resolution', 'spearhead']
# GBR AFG 1058
# ['base', 'Party', 'wound', 'deploy', 'soldier']
# GBR PAK 477
# ['Tour', 'Party', 'area', 'employer', 'Singapore']
# PRK USA 3163
# ['lure', 'cite', 'Tour', 'intercept', 'shun']
# PRK IGOUNO 804
# ['attend', 'shun', 'Party', 'expel', 'kick']
# PRK CHN 578
# ['boycott', 'Singapore', 'Tour', 'States', 'kick']
# PRK JPN 1566
# ['abducted', 'kidnap', 'Sea', 'admit', 'test-fired']
# PRK KOR 1510
# ['test-fired', 'defect', 'Party', 'acronym', 'stand']
# EGY IRQ 623
# ['Tour', 'destabilize', 'play', 'free', 'Party']
# EGY USA 837
# ['mediator', 'treaty', 'nation', 'Party', 'Tour']
# EGY ISR 3641
# ['state', 'nation', 'Party', 'country', 'mediator']
# EGY PSE 1640
# ['Singapore', 'last', 'forward', 'situation', 'Party']
# EGY IGOUNO 345
# ['mediator', 'Press', 'implementation', 'meeting', 'Party']
# EGY SDN 491
# ['government', 'mediator', 'stance', 'sever', 'Party']
# IGOEEC IRQ 483
# ['Press', 'Dollars', 'Symposium', 'last', 'Party']
# IGOEEC FRA 540
# ['denial', 'Press', 'Austria', 'clear', 'Luxembourg']
# IGOEEC USA 1361
# ['Singapore', 'Luxembourg', 'Press', 'Party', 'Tour']
# IGOEEC GBR 333
# ['Party', 'Press', 'Singapore', 'Luxembourg', 'Austria']
# IGOEEC ISR 1063
# ['last', 'draft', 'killing', 'Party', 'right']
# IGOEEC PSE 1100
# ['Press', 'donor', 'draft', 'freeze', 'envisage']
# IGOEEC DEU 352
# ['_', 'denial', 'Austria', 'Press', 'Luxembourg']
# IGOEEC IGOUNO 1103
# ['Party', 'Press', 'debate', 'refer', 'draft']
# IGOEEC CHN 496
# ['Symposium', 'Party', 'Tour', 'cede', 'Singapore']
# IGOEEC IGONAT 224
# ['expansion', 'forward', 'draft', 'Press', 'Party']
# IGOEEC RUS 1073
# ['Luxembourg', 'Austria', 'objection', 'Party', 'cede']
# IGOEEC IRN 1265
# ['mastery', 'freeze', 'refer', 'negotiator', 'program']
# IGOEEC GRC 497
# ['coup', 'last', 'Luxembourg', 'apply', 'admit']
# IGOEEC SRB 443
# ['independence', 'last', 'hide', 'draft', 'Party']
# IGOEEC TUR 1163
# ['caution', 'list', 'assess', 'progress', 'PKK']
# IGOEEC MMR 284
# ['denial', 'Press', 'ruler', 'prisoner', 'tighten']
# IGOEEC CYP 448
# ['guarantor', 'foresee', 'reunification', 'prefer', 'island']
# IGOEEC ESP 293
# ['Luxembourg', 'comprise', 'Austria', 'denial', 'Party']
# IGOEEC KSV 446
# ['recommend', 'status', 'statehood', 'draft', 'independence']
# LBN USA 296
# ['seizure', 'hopeful', 'Press', 'Party', 'Singapore']
# LBN ISR 1614
# ['hopeful', 'wound', 'neighbor', 'Party', 'Singapore']
# LBN IGOUNO 581
# ['violation', 'Party', 'chapter', 'Singapore', 'Press']
# LBN SYR 594
# ['Singapore', 'bequeath', 'Press', 'reveal', 'Party']
# VNM USA 403
# ['hopeful', 'Tour', 'export', 'earn', 'Party']
# IRN IRQ 1885
# ['situation', 'militia', 'arm', 'Party', 'interfere']
# IRN FRA 348
# ['negotiation', 'resignation', 'Singapore', 'gesture', 'deny']
# IRN USA 3322
# ['destruction', 'Party', 'Singapore', 'Tour', 'deny']
# IRN GBR 723
# ['Party', 'seize', 'Singapore', 'deny', 'gesture']
# IRN ISR 1017
# ['trade', 'wipe', 'deny', 'recognize', 'destruction']
# IRN DEU 386
# ['minister', 'Symposium', 'Singapore', 'gesture', 'cloud']
# IRN IGOUNO 2582
# ['Party', 'cooperate', 'heed', 'refer', 'defy']
# IRN IGOEEC 523
# ['constitution', 'assessment', 'Union', 'Party', 'resignation']
# IRN RUS 659
# ['enrich', 'defy', 'Party', 'enable', 'pose']
# IRN LBN 277
# ['situation', 'Party', 'last', 'assassination', 'destruction']
# IRN AFG 708
# ['Party', 'interfere', 'border', 'drug', 'situation']
# IRN TUR 378
# ['PKK', 'Singapore', 'Tour', 'threat', 'deny']
# THA USA 361
# ['Cooperation', 'Party', 'come', 'Tour', 'map']
# THA MMR 452
# ['gunfire', 'conclude', 'prisoner', 'Tour', 'Association']
# THA KHM 380
# ['conclude', 'Association', 'award', 'downgrade', 'rule']
# TUR IRQ 3916
# ['PKK', 'Party', 'cross', 'border', 'mass']
# TUR USA 1510
# ['converge', 'PKK', 'Party', 'Press', 'Tour']
# TUR ISR 778
# ['Mediterranean', 'converge', 'friend', 'Tour', 'Party']
# TUR IGOUNO 447
# ['Tour', 'implementation', 'comply', 'Party', 'Press']
# TUR IGOEEC 1321
# ['realize', 'Party', 'Tour', 'Press', 'candidate']
# TUR SYR 435
# ['converge', 'border', 'Party', 'Istanbul', 'host']
# TUR IGONAT 307
# ['archipelago', 'Tour', 'invoke', 'Party', 'Press']
# TUR IRN 539
# ['Symposium', 'border', 'Party', 'suspect', 'converge']
# TUR GRC 1146
# ['last', 'Tour', 'blueprint', 'union', 'coup']
# TUR CYP 903
# ['year', 'delimitation', 'accession', 'guarantor', 'island']
# TUR X-TURCYP 704
# ['maintain', 'republic', 'declare', 'Republic', 'Party']
# AUS IRQ 930
# ['gunfire', 'invasion', 'Singapore', 'Dollars', 'Party']
# AUS USA 847
# ['Singapore', 'Party', 'Cooperation', 'Tour', 'ally']
# AUS IGOUNO 272
# ['Cooperation', 'chapter', 'Party', 'seat', 'contribute']
# AUS CHN 342
# ['Party', 'Cooperation', 'Tour', 'invitation', 'Singapore']
# AUS IDN 382
# ['annexation', 'gunfire', 'Afghanistan', 'sovereignty', 'route']
# HRV BIH 430
# ['requirement', 'rent', 'cross', 'enable', 'Party']
# HRV IGOUNO 366
# ['resignation', 'rent', 'requirement', 'enable', 'Party']
# HRV SRB 227
# ['enable', 'Party', 'halt', 'hide', 'campaign']
# TWN USA 592
# ['Party', 'rap', 'Tour', 'invest', 'lose']
# TWN IGOUNO 283
# ['split', 'part', 'Party', 'seat', 'lose']
# TWN CHN 1759
# ['affair', 'lose', 'territory', 'split', 'invest']
# CUB USA 936
# ['Singapore', 'dlr', 'hijack', 'cede', 'Party']
# UKR IGONAT 294
# ['Party', 'become', 'program', 'route', 'Partnership']
# UKR RUS 706
# ['Tour', 'export', 'Party', 'route', 'buy']
# TMP IDN 258
# ['split', 'secede', 'period', 'occupation', 'gain']
# CHNTIB CHN 287
# ['Singapore', 'investor', 'opposition', 'crackdown', 'affair']
# LBY USA 444
# ['surrender', 'Morocco', 'month', 'supervision', 'victim']
# LBY IGOUNO 380
# ['Party', 'Morocco', 'violate', 'defy', 'lifting']
# ESP IRQ 764
# ['invasion', 'Dollars', 'troops', 'soldier', 'coalition']
# ESP USA 538
# ['archipelago', 'Press', 'consultation', 'cloud', 'Dollars']
# ESP IGOUNO 317
# ['Dollars', 'contingent', 'serve', 'contributor', 'sponsor']
# ESP IGOEEC 416
# ['forefront', 'assume', 'candidate', 'sponsor', 'presidency']
# GEO RUS 1660
# ['accuse', 'Party', 'Sea', 'Singapore', 'accusation']
# ITA IRQ 904
# ['troops', 'serve', 'rebuild', 'Party', 'soldier']
# ITA USA 447
# ['contributor', 'forward', 'Press', 'supporter', 'Party']
# ITA IGOUNO 208
# ['Press', 'contingent', 'Party', 'serve', 'contributor']
# ITA IGOEEC 521
# ['forward', 'Party', 'assume', 'presidency', 'contributor']
# JOR IRQ 981
# ['kidnap', 'cloud', 'free', 'pinpoint', 'Party']
# JOR USA 518
# ['shoreline', 'Tour', 'Party', 'nation', 'side']
# JOR ISR 1864
# ['Party', 'sign', 'broker', 'nation', 'country']
# JOR PSE 598
# ['situation', 'pinpoint', 'forward', 'Authority', 'Party']
# SRB BIH 366
# ['fate', 'Dollars', 'commit', 'Party', 'Singapore']
# SRB IGOUNO 470
# ['Press', 'Singapore', 'Party', 'hundred', 'contributor']
# SRB HRV 197
# ['Singapore', 'abducted', 'commit', 'rent', 'authority']
# SRB KSV 853
# ['commit', 'recognize', 'statehood', 'declaration', 'independence']
# MMR THA 349
# ['cross', 'shut', 'ASEAN', 'close', 'envoy']
# MEX USA 730
# ['last', 'archipelago', 'forward', 'Tour', 'Party']
# POL IRQ 1062
# ['Party', 'soldier', 'interest', 'represent', 'command']
# POL USA 386
# ['Press', 'Party', 'join', 'command', 'represent']
# POL IGOEEC 654
# ['contributor', 'join', 'candidate', 'command', 'represent']
# POL IGONAT 365
# ['contributor', 'join', 'expansion', 'represent', 'command']
# POL RUS 332
# ['Singapore', 'forward', 'command', 'Party', 'represent']
# BIH IGOUNO 844
# ['take', 'intimidate', 'hundred', 'Press', 'Party']
# BIH IGONAT 227
# ['expansion', 'archipelago', 'take', 'Press', 'Party']
# BIH SRB 433
# ['campaign', 'cloud', 'sandwich', 'hide', 'Party']
# BIH HRV 215
# ['retaliate', 'intimidate', 'authority', 'Party', 'sandwich']
# IRL IGOEEC 310
# ['resignation', 'Tour', 'Party', 'assume', 'presidency']
# SAU IRQ 508
# ['fear', 'Tour', 'enable', 'destabilize', 'Party']
# SAU USA 724
# ['national', 'rap', 'shoreline', 'Party', 'Tour']
# SAU ISR 311
# ['rap', 'Tour', 'participant', 'enjoy', 'Party']
# KWT IRQ 935
# ['Tour', 'disappear', 'Party', 'War', 'liberate']
# KWT USA 564
# ['War', 'buy', 'ally', 'Tour', 'Party']
# CAN USA 504
# ['Light', 'Party', 'lose', 'Tour', 'Singapore']
# CAN AFG 518
# ['Party', 'train', 'soldier', 'deploy', 'wound']
# COL USA 499
# ['Cooperation', 'receive', 'Tour', 'trafficker', 'extradite']
# AFG USA 618
# ['requirement', 'abduction', 'Singapore', 'adherence', 'Party']
# AFG PAK 1018
# ['live', 'hide', 'shelter', 'area', 'haven']
# RWA COD 412
# ['Press', 'cloud', 'refuge', 'live', 'flee']
# RWA COG 559
# ['last', 'Singapore', 'Party', 'coalition', 'flee']
# UGA SDN 495
# ['resignation', 'Party', 'pursue', 'sever', 'break']
# UGA COG 387
# ['fight', 'deploy', 'forward', 'Party', 'coalition']
# PHL IRQ 439
# ['order', 'coalition', 'expel', 'Party', 'deploy']
# PHL USA 672
# ['warrant', 'haggle', 'archipelago', 'Tour', 'Party']
# PHL CHN 336
# ['invitation', 'Symposium', 'Party', 'Tour', 'conclude']
# BLR RUS 278
# ['Morocco', 'application', 'objection', 'convince', 'buy']
# MYS USA 400
# ['Sunday', 'greet', 'Singapore', 'Party', 'Tour']
# ERI ETH 382
# ['cloud', 'repulse', 'Party', 'accusation', 'gain']
# ROU IGOEEC 396
# ['communism', 'Party', 'Union', 'apply', 'hope']
# BGR IRQ 379
# ['enable', 'station', 'serve', 'Party', 'soldier']
# BGR IGOEEC 410
# ['Press', 'route', 'communism', 'apply', 'Party']
# CYP IGOUNO 337
# ['bulk', 'protest', 'implementation', 'July', 'Press']
# CYP IGOEEC 724
# ['candidate', 'Nations', 'split', 'constitution', 'apply']
# CYP GRC 383
# ['blueprint', 'remain', 'apply', 'split', 'coup']
# CYP TUR 317
# ['prove', 'Singapore', 'Nations', 'Tour', 'protest']
# VEN USA 791
# ['Singapore', 'Tour', 'supplier', 'Party', 'oil']
# VEN COL 506
# ['close', 'July', 'Press', 'border', 'Party']
# KSV IGOUNO 545
# ['Symposium', 'Party', 'be', 'seat', 'province']
# KSV SRB 1064
# ['Party', 'protectorate', 'opposition', 'breakup', 'province']
# ETH SOM 802
# ['Tour', 'Party', 'roll', 'government', 'intervene']
# ETH ERI 340
# ['Party', 'Africa', 'Tour', 'accusation', 'panel']
# NLD IGOEEC 274
# ['forward', 'Singapore', 'constitution', 'Party', 'Tour']
# ALB SRB 288
# ['opposition', 'breakup', 'Tour', 'ally', 'proclaim']
# ALB KSV 157
# ['grant', 'Tour', 'Dollars', 'status', 'independence']
# TCD SDN 404
# ['Singapore', 'blame', 'Party', 'break', 'close']
# DNK IRQ 506
# ['troops', 'deploy', 'Party', 'station', 'soldier']
